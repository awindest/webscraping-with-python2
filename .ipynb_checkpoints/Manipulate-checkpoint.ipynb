# %%
#
# This tiny python script scrapes the talendforge.org web site for a list of Talend components and their corresponding
# categories (families) and creates a hierarchy and writes the hierarchy to a json file to be input into an Observable
# notebook for visualizing the data.
#
import requests
from bs4 import BeautifulSoup
import json 
# need this to get correct response from web site
parameters = {
    'version':'254',
    'edition':'13',
    'ALL':'Show All'
}
#
# To find the above parameters:
# Open up Developer Tools in Chrome by selecting View > Developer > Developer Tools.
# Select the Network Tab.
# Visit the page you’re going to do your search from.
# Click the Clear button and then submit your form.
# The Network tab will fill with activity!
# Find the thing in the Network tab that looks like the same name as your webpage. Click it. In this case it was index.php
# On the right-hand side you get a new pane. Scroll down, keep scrolling, yep, all the way down until you see
# Form Data. Those are the parameters I found for version, edition and ALL.
#
# Refer to: http://jonathansoma.com/lede/foundations-2017/classes/adv-scraping/advanced-scraping-form-submission/

# we are doing a post here instead of the usual get because we are scraping a form. It gets trickier if we have to 
# submit headers.
req = requests.post("http://www.talendforge.org/components/index.php", data = parameters)

# If you are going to be testing a lot, then write out the file to be polite to the web server 
# and observe web scraping etiquette. Your mother will love you for it.

# and the magic begins (lxml is the faster parser and recommended by BeautifulSoup. See docs.)
soup = BeautifulSoup(req.content, 'lxml')

# start with all targeted divs, then descend down the hierarchy
# as appropriate. We found out via viewing the source of the web page that we are interested in 
# two classe: "family" (category) and "line_component"
divs = soup.find_all('div', class_=['family','line_component'])

# family and line_component counters for data viz parameters
i = j = 0
# create main dictionary and initialize top element
data_fabric = {}
data_fabric['name'] = "Talend Data Fabric"
data_fabric['children'] = []

#
# need to inspect web page to test the following logic (in case web page has changed).
# this logic was driven by the fact that the family div and the div where the component information
# resided were at the same level; no explict parent:child relationship defined but the relationship was 
# implicit based upon position or sequence in the web page so the family category was decoupled from
# the component info.
#
# initialize first family value; this is our trigger to add family and component children to dictionary
# and start a new list of components
oldfamily = ""
#create list to store components
listofcomponents = []
# loop over all the divs returned from BeautifulSoup's find_all
for div in divs:
    classname = div.get('class',[''])[0] #stolen from stackoverflow 8)
    if classname == 'family':
        family = div.text.strip()
        if (family != oldfamily): #indicates we are at another level
            data_fabric['children'].append({'name':oldfamily,'children':listofcomponents})
            oldfamily = family
            print("Components List", family,"::", listofcomponents)
        # reset list
            listofcomponents = []
        j = j + 1 #family counter
    elif classname =='line_component':
        # this may be overkill but its Sunday morning and I want to finish this
        name = div.find(class_='name').find('a').string.strip()
        # construct list of components
        listofcomponents.append({'name':name,'value':i})

        print("\t", i, family, name)
        i = i + 1 # component counter
#output file
with open('data_fabric.json', 'w') as outfile:
    json.dump(data_fabric, outfile, indent=1)
# need this info for Observablehq work (data viz)    
print("Statistics:\n Number of families:\t", j,"\n Number of components:\t", i)
# Out:
# Components List Authentication :: []
# 	 0 Authentication tSetKeystore
# Components List AWS :: [{'name': 'tSetKeystore', 'value': 0}]
# 	 1 AWS cAWSConnection
# 	 2 AWS cAWSS3
# 	 3 AWS cAWSSES
# 	 4 AWS cAWSSNS
# 	 5 AWS cAWSSQS
# Components List Big Data :: [{'name': 'cAWSConnection', 'value': 1}, {'name': 'cAWSS3', 'value': 2}, {'name': 'cAWSSES', 'value': 3}, {'name': 'cAWSSNS', 'value': 4}, {'name': 'cAWSSQS', 'value': 5}]
# 	 6 Big Data tBigQueryBulkExec
# 	 7 Big Data tBigQueryInput
# 	 8 Big Data tBigQueryOutput
# 	 9 Big Data tBigQueryOutputBulk
# 	 10 Big Data tBigQuerySQLRow
# 	 11 Big Data tCassandraBulkExec
# 	 12 Big Data tCassandraClose
# 	 13 Big Data tCassandraConnection
# 	 14 Big Data tCassandraInput
# 	 15 Big Data tCassandraOutput
# 	 16 Big Data tCassandraOutputBulk
# 	 17 Big Data tCassandraOutputBulkExec
# 	 18 Big Data tCassandraRow
# 	 19 Big Data tDBFSConnection
# 	 20 Big Data tDBFSGet
# 	 21 Big Data tDBFSPut
# 	 22 Big Data tDynamoDBInput
# 	 23 Big Data tDynamoDBOutput
# 	 24 Big Data tGSBucketCreate
# 	 25 Big Data tGSBucketDelete
# 	 26 Big Data tGSBucketExist
# 	 27 Big Data tGSBucketList
# 	 28 Big Data tGSClose
# 	 29 Big Data tGSConnection
# 	 30 Big Data tGSCopy
# 	 31 Big Data tGSDelete
# 	 32 Big Data tGSGet
# 	 33 Big Data tGSList
# 	 34 Big Data tGSPut
# 	 35 Big Data tHBaseClose
# 	 36 Big Data tHBaseConnection
# 	 37 Big Data tHBaseInput
# 	 38 Big Data tHBaseOutput
# 	 39 Big Data tHCatalogInput
# 	 40 Big Data tHCatalogLoad
# 	 41 Big Data tHCatalogOperation
# 	 42 Big Data tHCatalogOutput
# 	 43 Big Data tHDFSCompare
# 	 44 Big Data tHDFSConnection
# 	 45 Big Data tHDFSCopy
# 	 46 Big Data tHDFSDelete
# 	 47 Big Data tHDFSExist
# 	 48 Big Data tHDFSGet
# 	 49 Big Data tHDFSInput
# 	 50 Big Data tHDFSList
# 	 51 Big Data tHDFSOutput
# 	 52 Big Data tHDFSOutputRaw
# 	 53 Big Data tHDFSProperties
# 	 54 Big Data tHDFSPut
# 	 55 Big Data tHDFSRename
# 	 56 Big Data tHDFSRowCount
# 	 57 Big Data tHiveClose
# 	 58 Big Data tHiveConnection
# 	 59 Big Data tHiveCreateTable
# 	 60 Big Data tHiveInput
# 	 61 Big Data tHiveLoad
# 	 62 Big Data tHiveRow
# 	 63 Big Data tImpalaClose
# 	 64 Big Data tImpalaConnection
# 	 65 Big Data tImpalaCreateTable
# 	 66 Big Data tImpalaInput
# 	 67 Big Data tImpalaLoad
# 	 68 Big Data tImpalaOutput
# 	 69 Big Data tImpalaRow
# 	 70 Big Data tMapRDBClose
# 	 71 Big Data tMapRDBConnection
# 	 72 Big Data tMapRDBInput
# 	 73 Big Data tMapRDBOutput
# 	 74 Big Data tMapRStreamsConnection
# 	 75 Big Data tMarkLogicBulkLoad
# 	 76 Big Data tMarkLogicClose
# 	 77 Big Data tMarkLogicConnection
# 	 78 Big Data tMarkLogicInput
# 	 79 Big Data tMarkLogicOutput
# 	 80 Big Data tMongoDBBulkLoad
# 	 81 Big Data tMongoDBClose
# 	 82 Big Data tMongoDBConnection
# 	 83 Big Data tMongoDBGridFSDelete
# 	 84 Big Data tMongoDBGridFSGet
# 	 85 Big Data tMongoDBGridFSList
# 	 86 Big Data tMongoDBGridFSProperties
# 	 87 Big Data tMongoDBGridFSPut
# 	 88 Big Data tMongoDBInput
# 	 89 Big Data tMongoDBOutput
# 	 90 Big Data tMongoDBRow
# 	 91 Big Data tNeo4jBatchOutput
# 	 92 Big Data tNeo4jBatchOutputRelationship
# 	 93 Big Data tNeo4jBatchSchema
# 	 94 Big Data tNeo4jClose
# 	 95 Big Data tNeo4jConnection
# 	 96 Big Data tNeo4jImportTool
# 	 97 Big Data tNeo4jInput
# 	 98 Big Data tNeo4jOutput
# 	 99 Big Data tNeo4jOutputRelationship
# 	 100 Big Data tNeo4jRow
# 	 101 Big Data tRiakBucketList
# 	 102 Big Data tRiakClose
# 	 103 Big Data tRiakConnection
# 	 104 Big Data tRiakInput
# 	 105 Big Data tRiakKeyList
# 	 106 Big Data tRiakOutput
# 	 107 Big Data tSqoopExport
# 	 108 Big Data tSqoopImport
# 	 109 Big Data tSqoopImportAllTables
# 	 110 Big Data tSqoopMerge
# Components List Business :: [{'name': 'tBigQueryBulkExec', 'value': 6}, {'name': 'tBigQueryInput', 'value': 7}, {'name': 'tBigQueryOutput', 'value': 8}, {'name': 'tBigQueryOutputBulk', 'value': 9}, {'name': 'tBigQuerySQLRow', 'value': 10}, {'name': 'tCassandraBulkExec', 'value': 11}, {'name': 'tCassandraClose', 'value': 12}, {'name': 'tCassandraConnection', 'value': 13}, {'name': 'tCassandraInput', 'value': 14}, {'name': 'tCassandraOutput', 'value': 15}, {'name': 'tCassandraOutputBulk', 'value': 16}, {'name': 'tCassandraOutputBulkExec', 'value': 17}, {'name': 'tCassandraRow', 'value': 18}, {'name': 'tDBFSConnection', 'value': 19}, {'name': 'tDBFSGet', 'value': 20}, {'name': 'tDBFSPut', 'value': 21}, {'name': 'tDynamoDBInput', 'value': 22}, {'name': 'tDynamoDBOutput', 'value': 23}, {'name': 'tGSBucketCreate', 'value': 24}, {'name': 'tGSBucketDelete', 'value': 25}, {'name': 'tGSBucketExist', 'value': 26}, {'name': 'tGSBucketList', 'value': 27}, {'name': 'tGSClose', 'value': 28}, {'name': 'tGSConnection', 'value': 29}, {'name': 'tGSCopy', 'value': 30}, {'name': 'tGSDelete', 'value': 31}, {'name': 'tGSGet', 'value': 32}, {'name': 'tGSList', 'value': 33}, {'name': 'tGSPut', 'value': 34}, {'name': 'tHBaseClose', 'value': 35}, {'name': 'tHBaseConnection', 'value': 36}, {'name': 'tHBaseInput', 'value': 37}, {'name': 'tHBaseOutput', 'value': 38}, {'name': 'tHCatalogInput', 'value': 39}, {'name': 'tHCatalogLoad', 'value': 40}, {'name': 'tHCatalogOperation', 'value': 41}, {'name': 'tHCatalogOutput', 'value': 42}, {'name': 'tHDFSCompare', 'value': 43}, {'name': 'tHDFSConnection', 'value': 44}, {'name': 'tHDFSCopy', 'value': 45}, {'name': 'tHDFSDelete', 'value': 46}, {'name': 'tHDFSExist', 'value': 47}, {'name': 'tHDFSGet', 'value': 48}, {'name': 'tHDFSInput', 'value': 49}, {'name': 'tHDFSList', 'value': 50}, {'name': 'tHDFSOutput', 'value': 51}, {'name': 'tHDFSOutputRaw', 'value': 52}, {'name': 'tHDFSProperties', 'value': 53}, {'name': 'tHDFSPut', 'value': 54}, {'name': 'tHDFSRename', 'value': 55}, {'name': 'tHDFSRowCount', 'value': 56}, {'name': 'tHiveClose', 'value': 57}, {'name': 'tHiveConnection', 'value': 58}, {'name': 'tHiveCreateTable', 'value': 59}, {'name': 'tHiveInput', 'value': 60}, {'name': 'tHiveLoad', 'value': 61}, {'name': 'tHiveRow', 'value': 62}, {'name': 'tImpalaClose', 'value': 63}, {'name': 'tImpalaConnection', 'value': 64}, {'name': 'tImpalaCreateTable', 'value': 65}, {'name': 'tImpalaInput', 'value': 66}, {'name': 'tImpalaLoad', 'value': 67}, {'name': 'tImpalaOutput', 'value': 68}, {'name': 'tImpalaRow', 'value': 69}, {'name': 'tMapRDBClose', 'value': 70}, {'name': 'tMapRDBConnection', 'value': 71}, {'name': 'tMapRDBInput', 'value': 72}, {'name': 'tMapRDBOutput', 'value': 73}, {'name': 'tMapRStreamsConnection', 'value': 74}, {'name': 'tMarkLogicBulkLoad', 'value': 75}, {'name': 'tMarkLogicClose', 'value': 76}, {'name': 'tMarkLogicConnection', 'value': 77}, {'name': 'tMarkLogicInput', 'value': 78}, {'name': 'tMarkLogicOutput', 'value': 79}, {'name': 'tMongoDBBulkLoad', 'value': 80}, {'name': 'tMongoDBClose', 'value': 81}, {'name': 'tMongoDBConnection', 'value': 82}, {'name': 'tMongoDBGridFSDelete', 'value': 83}, {'name': 'tMongoDBGridFSGet', 'value': 84}, {'name': 'tMongoDBGridFSList', 'value': 85}, {'name': 'tMongoDBGridFSProperties', 'value': 86}, {'name': 'tMongoDBGridFSPut', 'value': 87}, {'name': 'tMongoDBInput', 'value': 88}, {'name': 'tMongoDBOutput', 'value': 89}, {'name': 'tMongoDBRow', 'value': 90}, {'name': 'tNeo4jBatchOutput', 'value': 91}, {'name': 'tNeo4jBatchOutputRelationship', 'value': 92}, {'name': 'tNeo4jBatchSchema', 'value': 93}, {'name': 'tNeo4jClose', 'value': 94}, {'name': 'tNeo4jConnection', 'value': 95}, {'name': 'tNeo4jImportTool', 'value': 96}, {'name': 'tNeo4jInput', 'value': 97}, {'name': 'tNeo4jOutput', 'value': 98}, {'name': 'tNeo4jOutputRelationship', 'value': 99}, {'name': 'tNeo4jRow', 'value': 100}, {'name': 'tRiakBucketList', 'value': 101}, {'name': 'tRiakClose', 'value': 102}, {'na ...
# 	 111 Business tBonitaDeploy
# 	 112 Business tBonitaInstantiateProcess
# 	 113 Business tJIRAInput
# 	 114 Business tJIRAOutput
# 	 115 Business tMarketoBulkExec
# 	 116 Business tMarketoCampaign
# 	 117 Business tMarketoConnection
# 	 118 Business tMarketoInput
# 	 119 Business tMarketoListOperation
# 	 120 Business tMarketoOutput
# 	 121 Business tMicrosoftCrmInput
# 	 122 Business tMicrosoftCrmOutput
# 	 123 Business tNetsuiteConnection
# 	 124 Business tNetsuiteInput
# 	 125 Business tNetsuiteOutput
# 	 126 Business tOpenbravoERPInput
# 	 127 Business tOpenbravoERPOutput
# 	 128 Business tSalesforceBulkExec
# 	 129 Business tSalesforceConnection
# 	 130 Business tSalesforceEinsteinBulkExec
# 	 131 Business tSalesforceEinsteinOutputBulkExec
# 	 132 Business tSalesforceGetDeleted
# 	 133 Business tSalesforceGetServerTimestamp
# 	 134 Business tSalesforceGetUpdated
# 	 135 Business tSalesforceInput
# 	 136 Business tSalesforceOutput
# 	 137 Business tSalesforceOutputBulk
# 	 138 Business tSalesforceOutputBulkExec
# 	 139 Business tSAPADSOInput
# 	 140 Business tSAPBapi
# 	 141 Business tSAPBWInput
# 	 142 Business tSAPCommit
# 	 143 Business tSAPConnection
# 	 144 Business tSAPDataSourceOutput
# 	 145 Business tSAPDataSourceReceiver
# 	 146 Business tSAPDSOInput
# 	 147 Business tSAPDSOOutput
# 	 148 Business tSAPIDocInput
# 	 149 Business tSAPIDocOutput
# 	 150 Business tSAPIDocReceiver
# 	 151 Business tSAPInfoCubeInput
# 	 152 Business tSAPInfoObjectInput
# 	 153 Business tSAPInfoObjectOutput
# 	 154 Business tSAPODPInput
# 	 155 Business tSAPRollback
# 	 156 Business tSAPTableInput
# 	 157 Business tServiceNowConnection
# 	 158 Business tServiceNowInput
# 	 159 Business tServiceNowOutput
# 	 160 Business tVtigerCRMInput
# 	 161 Business tVtigerCRMOutput
# 	 162 Business tWorkdayInput
# Components List Business Intelligence :: [{'name': 'tBonitaDeploy', 'value': 111}, {'name': 'tBonitaInstantiateProcess', 'value': 112}, {'name': 'tJIRAInput', 'value': 113}, {'name': 'tJIRAOutput', 'value': 114}, {'name': 'tMarketoBulkExec', 'value': 115}, {'name': 'tMarketoCampaign', 'value': 116}, {'name': 'tMarketoConnection', 'value': 117}, {'name': 'tMarketoInput', 'value': 118}, {'name': 'tMarketoListOperation', 'value': 119}, {'name': 'tMarketoOutput', 'value': 120}, {'name': 'tMicrosoftCrmInput', 'value': 121}, {'name': 'tMicrosoftCrmOutput', 'value': 122}, {'name': 'tNetsuiteConnection', 'value': 123}, {'name': 'tNetsuiteInput', 'value': 124}, {'name': 'tNetsuiteOutput', 'value': 125}, {'name': 'tOpenbravoERPInput', 'value': 126}, {'name': 'tOpenbravoERPOutput', 'value': 127}, {'name': 'tSalesforceBulkExec', 'value': 128}, {'name': 'tSalesforceConnection', 'value': 129}, {'name': 'tSalesforceEinsteinBulkExec', 'value': 130}, {'name': 'tSalesforceEinsteinOutputBulkExec', 'value': 131}, {'name': 'tSalesforceGetDeleted', 'value': 132}, {'name': 'tSalesforceGetServerTimestamp', 'value': 133}, {'name': 'tSalesforceGetUpdated', 'value': 134}, {'name': 'tSalesforceInput', 'value': 135}, {'name': 'tSalesforceOutput', 'value': 136}, {'name': 'tSalesforceOutputBulk', 'value': 137}, {'name': 'tSalesforceOutputBulkExec', 'value': 138}, {'name': 'tSAPADSOInput', 'value': 139}, {'name': 'tSAPBapi', 'value': 140}, {'name': 'tSAPBWInput', 'value': 141}, {'name': 'tSAPCommit', 'value': 142}, {'name': 'tSAPConnection', 'value': 143}, {'name': 'tSAPDataSourceOutput', 'value': 144}, {'name': 'tSAPDataSourceReceiver', 'value': 145}, {'name': 'tSAPDSOInput', 'value': 146}, {'name': 'tSAPDSOOutput', 'value': 147}, {'name': 'tSAPIDocInput', 'value': 148}, {'name': 'tSAPIDocOutput', 'value': 149}, {'name': 'tSAPIDocReceiver', 'value': 150}, {'name': 'tSAPInfoCubeInput', 'value': 151}, {'name': 'tSAPInfoObjectInput', 'value': 152}, {'name': 'tSAPInfoObjectOutput', 'value': 153}, {'name': 'tSAPODPInput', 'value': 154}, {'name': 'tSAPRollback', 'value': 155}, {'name': 'tSAPTableInput', 'value': 156}, {'name': 'tServiceNowConnection', 'value': 157}, {'name': 'tServiceNowInput', 'value': 158}, {'name': 'tServiceNowOutput', 'value': 159}, {'name': 'tVtigerCRMInput', 'value': 160}, {'name': 'tVtigerCRMOutput', 'value': 161}, {'name': 'tWorkdayInput', 'value': 162}]
# 	 163 Business Intelligence tBarChart
# 	 164 Business Intelligence tDB2SCD
# 	 165 Business Intelligence tDB2SCDELT
# 	 166 Business Intelligence tGreenplumSCD
# 	 167 Business Intelligence tInformixSCD
# 	 168 Business Intelligence tIngresSCD
# 	 169 Business Intelligence tJasperOutput
# 	 170 Business Intelligence tJasperOutputExec
# 	 171 Business Intelligence tJDBCSCDELT
# 	 172 Business Intelligence tLineChart
# 	 173 Business Intelligence tMondrianInput
# 	 174 Business Intelligence tMSSqlSCD
# 	 175 Business Intelligence tMysqlSCD
# 	 176 Business Intelligence tMysqlSCDELT
# 	 177 Business Intelligence tNetezzaSCD
# 	 178 Business Intelligence tOracleSCD
# 	 179 Business Intelligence tOracleSCDELT
# 	 180 Business Intelligence tPaloCheckElements
# 	 181 Business Intelligence tPaloClose
# 	 182 Business Intelligence tPaloConnection
# 	 183 Business Intelligence tPaloCube
# 	 184 Business Intelligence tPaloCubeList
# 	 185 Business Intelligence tPaloDatabase
# 	 186 Business Intelligence tPaloDatabaseList
# 	 187 Business Intelligence tPaloDimension
# 	 188 Business Intelligence tPaloDimensionList
# 	 189 Business Intelligence tPaloInputMulti
# 	 190 Business Intelligence tPaloOutput
# 	 191 Business Intelligence tPaloOutputMulti
# 	 192 Business Intelligence tPaloRule
# 	 193 Business Intelligence tPaloRuleList
# 	 194 Business Intelligence tParAccelSCD
# 	 195 Business Intelligence tPostgresPlusSCD
# 	 196 Business Intelligence tPostgresPlusSCDELT
# 	 197 Business Intelligence tPostgresqlSCD
# 	 198 Business Intelligence tPostgresqlSCDELT
# 	 199 Business Intelligence tSplunkEventCollector
# 	 200 Business Intelligence tSybaseSCD
# 	 201 Business Intelligence tSybaseSCDELT
# 	 202 Business Intelligence tTeradataSCD
# 	 203 Business Intelligence tTeradataSCDELT
# 	 204 Business Intelligence tVerticaSCD
# Components List Cloud :: [{'name': 'tBarChart', 'value': 163}, {'name': 'tDB2SCD', 'value': 164}, {'name': 'tDB2SCDELT', 'value': 165}, {'name': 'tGreenplumSCD', 'value': 166}, {'name': 'tInformixSCD', 'value': 167}, {'name': 'tIngresSCD', 'value': 168}, {'name': 'tJasperOutput', 'value': 169}, {'name': 'tJasperOutputExec', 'value': 170}, {'name': 'tJDBCSCDELT', 'value': 171}, {'name': 'tLineChart', 'value': 172}, {'name': 'tMondrianInput', 'value': 173}, {'name': 'tMSSqlSCD', 'value': 174}, {'name': 'tMysqlSCD', 'value': 175}, {'name': 'tMysqlSCDELT', 'value': 176}, {'name': 'tNetezzaSCD', 'value': 177}, {'name': 'tOracleSCD', 'value': 178}, {'name': 'tOracleSCDELT', 'value': 179}, {'name': 'tPaloCheckElements', 'value': 180}, {'name': 'tPaloClose', 'value': 181}, {'name': 'tPaloConnection', 'value': 182}, {'name': 'tPaloCube', 'value': 183}, {'name': 'tPaloCubeList', 'value': 184}, {'name': 'tPaloDatabase', 'value': 185}, {'name': 'tPaloDatabaseList', 'value': 186}, {'name': 'tPaloDimension', 'value': 187}, {'name': 'tPaloDimensionList', 'value': 188}, {'name': 'tPaloInputMulti', 'value': 189}, {'name': 'tPaloOutput', 'value': 190}, {'name': 'tPaloOutputMulti', 'value': 191}, {'name': 'tPaloRule', 'value': 192}, {'name': 'tPaloRuleList', 'value': 193}, {'name': 'tParAccelSCD', 'value': 194}, {'name': 'tPostgresPlusSCD', 'value': 195}, {'name': 'tPostgresPlusSCDELT', 'value': 196}, {'name': 'tPostgresqlSCD', 'value': 197}, {'name': 'tPostgresqlSCDELT', 'value': 198}, {'name': 'tSplunkEventCollector', 'value': 199}, {'name': 'tSybaseSCD', 'value': 200}, {'name': 'tSybaseSCDELT', 'value': 201}, {'name': 'tTeradataSCD', 'value': 202}, {'name': 'tTeradataSCDELT', 'value': 203}, {'name': 'tVerticaSCD', 'value': 204}]
# 	 205 Cloud tAmazonAuroraClose
# 	 206 Cloud tAmazonAuroraCommit
# 	 207 Cloud tAmazonAuroraConnection
# 	 208 Cloud tAmazonAuroraInput
# 	 209 Cloud tAmazonAuroraOutput
# 	 210 Cloud tAmazonAuroraRollback
# 	 211 Cloud tAmazonEMRListInstances
# 	 212 Cloud tAmazonEMRManage
# 	 213 Cloud tAmazonEMRResize
# 	 214 Cloud tAmazonMysqlClose
# 	 215 Cloud tAmazonMysqlCommit
# 	 216 Cloud tAmazonMysqlConnection
# 	 217 Cloud tAmazonMysqlInput
# 	 218 Cloud tAmazonMysqlOutput
# 	 219 Cloud tAmazonMysqlRollback
# 	 220 Cloud tAmazonMysqlRow
# 	 221 Cloud tAmazonOracleClose
# 	 222 Cloud tAmazonOracleCommit
# 	 223 Cloud tAmazonOracleConnection
# 	 224 Cloud tAmazonOracleInput
# 	 225 Cloud tAmazonOracleOutput
# 	 226 Cloud tAmazonOracleRollback
# 	 227 Cloud tAmazonOracleRow
# 	 228 Cloud tAmazonRedshiftManage
# 	 229 Cloud tAzureAdlsGen2Input
# 	 230 Cloud tAzureAdlsGen2Output
# 	 231 Cloud tAzureStorageConnection
# 	 232 Cloud tAzureStorageContainerCreate
# 	 233 Cloud tAzureStorageContainerDelete
# 	 234 Cloud tAzureStorageContainerExist
# 	 235 Cloud tAzureStorageContainerList
# 	 236 Cloud tAzureStorageDelete
# 	 237 Cloud tAzureStorageGet
# 	 238 Cloud tAzureStorageInputTable
# 	 239 Cloud tAzureStorageList
# 	 240 Cloud tAzureStorageOutputTable
# 	 241 Cloud tAzureStoragePut
# 	 242 Cloud tAzureStorageQueueCreate
# 	 243 Cloud tAzureStorageQueueDelete
# 	 244 Cloud tAzureStorageQueueInput
# 	 245 Cloud tAzureStorageQueueInputLoop
# 	 246 Cloud tAzureStorageQueueList
# 	 247 Cloud tAzureStorageQueueOutput
# 	 248 Cloud tAzureStorageQueuePurge
# 	 249 Cloud tBoxConnection
# 	 250 Cloud tBoxCopy
# 	 251 Cloud tBoxDelete
# 	 252 Cloud tBoxGet
# 	 253 Cloud tBoxList
# 	 254 Cloud tBoxPut
# 	 255 Cloud tCloudStart
# 	 256 Cloud tCloudStop
# 	 257 Cloud tCosmosDBBulkLoad
# 	 258 Cloud tCosmosDBConnection
# 	 259 Cloud tCosmosDBInput
# 	 260 Cloud tCosmosDBOutput
# 	 261 Cloud tCosmosDBRow
# 	 262 Cloud tDropboxConnection
# 	 263 Cloud tDropboxDelete
# 	 264 Cloud tDropboxGet
# 	 265 Cloud tDropboxList
# 	 266 Cloud tDropboxPut
# 	 267 Cloud tGoogleDataprocManage
# 	 268 Cloud tGoogleDriveConnection
# 	 269 Cloud tGoogleDriveCopy
# 	 270 Cloud tGoogleDriveCreate
# 	 271 Cloud tGoogleDriveDelete
# 	 272 Cloud tGoogleDriveGet
# 	 273 Cloud tGoogleDriveList
# 	 274 Cloud tGoogleDrivePut
# 	 275 Cloud tGSBucketCreate
# 	 276 Cloud tGSBucketDelete
# 	 277 Cloud tGSBucketExist
# 	 278 Cloud tGSBucketList
# 	 279 Cloud tGSClose
# 	 280 Cloud tGSConnection
# 	 281 Cloud tGSCopy
# 	 282 Cloud tGSDelete
# 	 283 Cloud tGSGet
# 	 284 Cloud tGSList
# 	 285 Cloud tGSPut
# 	 286 Cloud tMarketoBulkExec
# 	 287 Cloud tMarketoCampaign
# 	 288 Cloud tMarketoConnection
# 	 289 Cloud tMarketoInput
# 	 290 Cloud tMarketoListOperation
# 	 291 Cloud tMarketoOutput
# 	 292 Cloud tNetsuiteInput
# 	 293 Cloud tNetsuiteOutput
# 	 294 Cloud tRedshiftBulkExec
# 	 295 Cloud tRedshiftClose
# 	 296 Cloud tRedshiftCommit
# 	 297 Cloud tRedshiftConnection
# 	 298 Cloud tRedshiftInput
# 	 299 Cloud tRedshiftOutput
# 	 300 Cloud tRedshiftOutputBulk
# 	 301 Cloud tRedshiftOutputBulkExec
# 	 302 Cloud tRedshiftRollback
# 	 303 Cloud tRedshiftRow
# 	 304 Cloud tRedshiftUnload
# 	 305 Cloud tS3BucketCreate
# 	 306 Cloud tS3BucketDelete
# 	 307 Cloud tS3BucketExist
# 	 308 Cloud tS3BucketList
# 	 309 Cloud tS3Close
# 	 310 Cloud tS3Connection
# 	 311 Cloud tS3Copy
# 	 312 Cloud tS3Delete
# 	 313 Cloud tS3Get
# 	 314 Cloud tS3List
# 	 315 Cloud tS3Put
# 	 316 Cloud tSalesforceBulkExec
# 	 317 Cloud tSalesforceConnection
# 	 318 Cloud tSalesforceEinsteinBulkExec
# 	 319 Cloud tSalesforceEinsteinOutputBulkExec
# 	 320 Cloud tSalesforceGetDeleted
# 	 321 Cloud tSalesforceGetServerTimestamp
# 	 322 Cloud tSalesforceGetUpdated
# 	 323 Cloud tSalesforceInput
# 	 324 Cloud tSalesforceOutput
# 	 325 Cloud tSalesforceOutputBulk
# 	 326 Cloud tSalesforceOutputBulkExec
# 	 327 Cloud tServiceNowConnection
# 	 328 Cloud tServiceNowInput
# 	 329 Cloud tServiceNowOutput
# 	 330 Cloud tSnowflakeBulkExec
# 	 331 Cloud tSnowflakeClose
# 	 332 Cloud tSnowflakeConnection
# 	 333 Cloud tSnowflakeInput
# 	 334 Cloud tSnowflakeOutput
# 	 335 Cloud tSnowflakeOutputBulk
# 	 336 Cloud tSnowflakeOutputBulkExec
# 	 337 Cloud tSnowflakeRow
# 	 338 Cloud tSQLDWHBulkExec
# 	 339 Cloud tSQLDWHClose
# 	 340 Cloud tSQLDWHCommit
# 	 341 Cloud tSQLDWHConnection
# 	 342 Cloud tSQLDWHInput
# 	 343 Cloud tSQLDWHOutput
# 	 344 Cloud tSQLDWHRollback
# 	 345 Cloud tSQLDWHRow
# 	 346 Cloud tSQSConnection
# 	 347 Cloud tSQSInput
# 	 348 Cloud tSQSMessageChangeVisibility
# 	 349 Cloud tSQSMessageDelete
# 	 350 Cloud tSQSOutput
# 	 351 Cloud tSQSQueueAttributes
# 	 352 Cloud tSQSQueueCreate
# 	 353 Cloud tSQSQueueDelete
# 	 354 Cloud tSQSQueueList
# 	 355 Cloud tSQSQueuePurge
# 	 356 Cloud tWorkdayInput
# Components List Connectivity :: [{'name': 'tAmazonAuroraClose', 'value': 205}, {'name': 'tAmazonAuroraCommit', 'value': 206}, {'name': 'tAmazonAuroraConnection', 'value': 207}, {'name': 'tAmazonAuroraInput', 'value': 208}, {'name': 'tAmazonAuroraOutput', 'value': 209}, {'name': 'tAmazonAuroraRollback', 'value': 210}, {'name': 'tAmazonEMRListInstances', 'value': 211}, {'name': 'tAmazonEMRManage', 'value': 212}, {'name': 'tAmazonEMRResize', 'value': 213}, {'name': 'tAmazonMysqlClose', 'value': 214}, {'name': 'tAmazonMysqlCommit', 'value': 215}, {'name': 'tAmazonMysqlConnection', 'value': 216}, {'name': 'tAmazonMysqlInput', 'value': 217}, {'name': 'tAmazonMysqlOutput', 'value': 218}, {'name': 'tAmazonMysqlRollback', 'value': 219}, {'name': 'tAmazonMysqlRow', 'value': 220}, {'name': 'tAmazonOracleClose', 'value': 221}, {'name': 'tAmazonOracleCommit', 'value': 222}, {'name': 'tAmazonOracleConnection', 'value': 223}, {'name': 'tAmazonOracleInput', 'value': 224}, {'name': 'tAmazonOracleOutput', 'value': 225}, {'name': 'tAmazonOracleRollback', 'value': 226}, {'name': 'tAmazonOracleRow', 'value': 227}, {'name': 'tAmazonRedshiftManage', 'value': 228}, {'name': 'tAzureAdlsGen2Input', 'value': 229}, {'name': 'tAzureAdlsGen2Output', 'value': 230}, {'name': 'tAzureStorageConnection', 'value': 231}, {'name': 'tAzureStorageContainerCreate', 'value': 232}, {'name': 'tAzureStorageContainerDelete', 'value': 233}, {'name': 'tAzureStorageContainerExist', 'value': 234}, {'name': 'tAzureStorageContainerList', 'value': 235}, {'name': 'tAzureStorageDelete', 'value': 236}, {'name': 'tAzureStorageGet', 'value': 237}, {'name': 'tAzureStorageInputTable', 'value': 238}, {'name': 'tAzureStorageList', 'value': 239}, {'name': 'tAzureStorageOutputTable', 'value': 240}, {'name': 'tAzureStoragePut', 'value': 241}, {'name': 'tAzureStorageQueueCreate', 'value': 242}, {'name': 'tAzureStorageQueueDelete', 'value': 243}, {'name': 'tAzureStorageQueueInput', 'value': 244}, {'name': 'tAzureStorageQueueInputLoop', 'value': 245}, {'name': 'tAzureStorageQueueList', 'value': 246}, {'name': 'tAzureStorageQueueOutput', 'value': 247}, {'name': 'tAzureStorageQueuePurge', 'value': 248}, {'name': 'tBoxConnection', 'value': 249}, {'name': 'tBoxCopy', 'value': 250}, {'name': 'tBoxDelete', 'value': 251}, {'name': 'tBoxGet', 'value': 252}, {'name': 'tBoxList', 'value': 253}, {'name': 'tBoxPut', 'value': 254}, {'name': 'tCloudStart', 'value': 255}, {'name': 'tCloudStop', 'value': 256}, {'name': 'tCosmosDBBulkLoad', 'value': 257}, {'name': 'tCosmosDBConnection', 'value': 258}, {'name': 'tCosmosDBInput', 'value': 259}, {'name': 'tCosmosDBOutput', 'value': 260}, {'name': 'tCosmosDBRow', 'value': 261}, {'name': 'tDropboxConnection', 'value': 262}, {'name': 'tDropboxDelete', 'value': 263}, {'name': 'tDropboxGet', 'value': 264}, {'name': 'tDropboxList', 'value': 265}, {'name': 'tDropboxPut', 'value': 266}, {'name': 'tGoogleDataprocManage', 'value': 267}, {'name': 'tGoogleDriveConnection', 'value': 268}, {'name': 'tGoogleDriveCopy', 'value': 269}, {'name': 'tGoogleDriveCreate', 'value': 270}, {'name': 'tGoogleDriveDelete', 'value': 271}, {'name': 'tGoogleDriveGet', 'value': 272}, {'name': 'tGoogleDriveList', 'value': 273}, {'name': 'tGoogleDrivePut', 'value': 274}, {'name': 'tGSBucketCreate', 'value': 275}, {'name': 'tGSBucketDelete', 'value': 276}, {'name': 'tGSBucketExist', 'value': 277}, {'name': 'tGSBucketList', 'value': 278}, {'name': 'tGSClose', 'value': 279}, {'name': 'tGSConnection', 'value': 280}, {'name': 'tGSCopy', 'value': 281}, {'name': 'tGSDelete', 'value': 282}, {'name': 'tGSGet', 'value': 283}, {'name': 'tGSList', 'value': 284}, {'name': 'tGSPut', 'value': 285}, {'name': 'tMarketoBulkExec', 'value': 286}, {'name': 'tMarketoCampaign', 'value': 287}, {'name': 'tMarketoConnection', 'value': 288}, {'name': 'tMarketoInput', 'value': 289}, {'name': 'tMarketoListOperation', 'value': 290}, {'name': 'tMarketoOutput', 'value': 291}, {'name': 'tNetsuiteInput', 'value': 292}, {'name': 't ...
# 	 357 Connectivity cAMQP
# 	 358 Connectivity cAWSConnection
# 	 359 Connectivity cAWSS3
# 	 360 Connectivity cAWSSES
# 	 361 Connectivity cAWSSNS
# 	 362 Connectivity cAWSSQS
# 	 363 Connectivity cFile
# 	 364 Connectivity cFtp
# 	 365 Connectivity cHttp
# 	 366 Connectivity cJMS
# 	 367 Connectivity cKafka
# 	 368 Connectivity cMail
# 	 369 Connectivity cMQConnectionFactory
# 	 370 Connectivity cMQTT
# 	 371 Connectivity cREST
# 	 372 Connectivity cSOAP
# 	 373 Connectivity cWMQ
# Components List Core :: [{'name': 'cAMQP', 'value': 357}, {'name': 'cAWSConnection', 'value': 358}, {'name': 'cAWSS3', 'value': 359}, {'name': 'cAWSSES', 'value': 360}, {'name': 'cAWSSNS', 'value': 361}, {'name': 'cAWSSQS', 'value': 362}, {'name': 'cFile', 'value': 363}, {'name': 'cFtp', 'value': 364}, {'name': 'cHttp', 'value': 365}, {'name': 'cJMS', 'value': 366}, {'name': 'cKafka', 'value': 367}, {'name': 'cMail', 'value': 368}, {'name': 'cMQConnectionFactory', 'value': 369}, {'name': 'cMQTT', 'value': 370}, {'name': 'cREST', 'value': 371}, {'name': 'cSOAP', 'value': 372}, {'name': 'cWMQ', 'value': 373}]
# 	 374 Core cDirect
# 	 375 Core cDirectVM
# 	 376 Core cExchangePattern
# 	 377 Core cJavaDSLProcessor
# 	 378 Core cMessagingEndpoint
# 	 379 Core cSEDA
# 	 380 Core cSetBody
# 	 381 Core cSetHeader
# 	 382 Core cSetProperty
# 	 383 Core cVM
# Components List Custom :: [{'name': 'cDirect', 'value': 374}, {'name': 'cDirectVM', 'value': 375}, {'name': 'cExchangePattern', 'value': 376}, {'name': 'cJavaDSLProcessor', 'value': 377}, {'name': 'cMessagingEndpoint', 'value': 378}, {'name': 'cSEDA', 'value': 379}, {'name': 'cSetBody', 'value': 380}, {'name': 'cSetHeader', 'value': 381}, {'name': 'cSetProperty', 'value': 382}, {'name': 'cVM', 'value': 383}]
# 	 384 Custom cBean
# 	 385 Custom cBeanRegister
# 	 386 Custom cConfig
# 	 387 Custom cProcessor
# Components List Custom Code :: [{'name': 'cBean', 'value': 384}, {'name': 'cBeanRegister', 'value': 385}, {'name': 'cConfig', 'value': 386}, {'name': 'cProcessor', 'value': 387}]
# 	 388 Custom Code tGroovy
# 	 389 Custom Code tGroovyFile
# 	 390 Custom Code tJava
# 	 391 Custom Code tJavaFlex
# 	 392 Custom Code tJavaMR
# 	 393 Custom Code tJavaRow
# 	 394 Custom Code tJavaStorm
# 	 395 Custom Code tLibraryLoad
# 	 396 Custom Code tSetDynamicSchema
# 	 397 Custom Code tSetGlobalVar
# Components List Data Quality :: [{'name': 'tGroovy', 'value': 388}, {'name': 'tGroovyFile', 'value': 389}, {'name': 'tJava', 'value': 390}, {'name': 'tJavaFlex', 'value': 391}, {'name': 'tJavaMR', 'value': 392}, {'name': 'tJavaRow', 'value': 393}, {'name': 'tJavaStorm', 'value': 394}, {'name': 'tLibraryLoad', 'value': 395}, {'name': 'tSetDynamicSchema', 'value': 396}, {'name': 'tSetGlobalVar', 'value': 397}]
# 	 398 Data Quality tAddCRCRow
# 	 399 Data Quality tAddressRowCloud
# 	 400 Data Quality tBatchAddressRowCloud
# 	 401 Data Quality tChangeFileEncoding
# 	 402 Data Quality tDataDecrypt
# 	 403 Data Quality tDataEncrypt
# 	 404 Data Quality tDataMasking
# 	 405 Data Quality tDataShuffling
# 	 406 Data Quality tDataUnmasking
# 	 407 Data Quality tDqReportRun
# 	 408 Data Quality tDuplicateRow
# 	 409 Data Quality tExtractRegexFields
# 	 410 Data Quality tFindRegexlibExpressions
# 	 411 Data Quality tFirstnameMatch
# 	 412 Data Quality tFuzzyMatch
# 	 413 Data Quality tFuzzyUniqRow
# 	 414 Data Quality tGenKey
# 	 415 Data Quality tGoogleAddressRow
# 	 416 Data Quality tGoogleGeocoder
# 	 417 Data Quality tGoogleMapLookup
# 	 418 Data Quality tIntervalMatch
# 	 419 Data Quality tJapaneseNumberNormalize
# 	 420 Data Quality tJapaneseTokenize
# 	 421 Data Quality tJapaneseTransliterate
# 	 422 Data Quality tLastRegexlibExpressions
# 	 423 Data Quality tLoqateAddressRow
# 	 424 Data Quality tMatchGroup
# 	 425 Data Quality tMatchIndex
# 	 426 Data Quality tMatchIndexPredict
# 	 427 Data Quality tMatchModel
# 	 428 Data Quality tMatchPairing
# 	 429 Data Quality tMatchPredict
# 	 430 Data Quality tMelissaDataAddress
# 	 431 Data Quality tMSSqlInvalidRows
# 	 432 Data Quality tMSSqlValidRows
# 	 433 Data Quality tMultiPatternCheck
# 	 434 Data Quality tMySQLInvalidRows
# 	 435 Data Quality tMySQLValidRows
# 	 436 Data Quality tOracleInvalidRows
# 	 437 Data Quality tOracleValidRows
# 	 438 Data Quality tPatternCheck
# 	 439 Data Quality tPatternExtract
# 	 440 Data Quality tPatternMasking
# 	 441 Data Quality tPatternUnmasking
# 	 442 Data Quality tPersonator
# 	 443 Data Quality tPostgresqlInvalidRows
# 	 444 Data Quality tPostgresqlValidRows
# 	 445 Data Quality tQASAddressRow
# 	 446 Data Quality tQASBatchAddressRow
# 	 447 Data Quality tRecordMatching
# 	 448 Data Quality tReplaceList
# 	 449 Data Quality tReservoirSampling
# 	 450 Data Quality tRuleSurvivorship
# 	 451 Data Quality tSchemaComplianceCheck
# 	 452 Data Quality tStandardizePhoneNumber
# 	 453 Data Quality tStandardizeRow
# 	 454 Data Quality tStem
# 	 455 Data Quality tSurviveFields
# 	 456 Data Quality tSynonymOutput
# 	 457 Data Quality tSynonymSearch
# 	 458 Data Quality tThresholdViolationAlert
# 	 459 Data Quality tTransliterate
# 	 460 Data Quality tUniqRow
# 	 461 Data Quality tUniservBTGeneric
# 	 462 Data Quality tUniservRTConvertName
# 	 463 Data Quality tUniservRTMailBulk
# 	 464 Data Quality tUniservRTMailOutput
# 	 465 Data Quality tUniservRTMailSearch
# 	 466 Data Quality tUniservRTPost
# 	 467 Data Quality tVerifyEmail
# Components List Databases :: [{'name': 'tAddCRCRow', 'value': 398}, {'name': 'tAddressRowCloud', 'value': 399}, {'name': 'tBatchAddressRowCloud', 'value': 400}, {'name': 'tChangeFileEncoding', 'value': 401}, {'name': 'tDataDecrypt', 'value': 402}, {'name': 'tDataEncrypt', 'value': 403}, {'name': 'tDataMasking', 'value': 404}, {'name': 'tDataShuffling', 'value': 405}, {'name': 'tDataUnmasking', 'value': 406}, {'name': 'tDqReportRun', 'value': 407}, {'name': 'tDuplicateRow', 'value': 408}, {'name': 'tExtractRegexFields', 'value': 409}, {'name': 'tFindRegexlibExpressions', 'value': 410}, {'name': 'tFirstnameMatch', 'value': 411}, {'name': 'tFuzzyMatch', 'value': 412}, {'name': 'tFuzzyUniqRow', 'value': 413}, {'name': 'tGenKey', 'value': 414}, {'name': 'tGoogleAddressRow', 'value': 415}, {'name': 'tGoogleGeocoder', 'value': 416}, {'name': 'tGoogleMapLookup', 'value': 417}, {'name': 'tIntervalMatch', 'value': 418}, {'name': 'tJapaneseNumberNormalize', 'value': 419}, {'name': 'tJapaneseTokenize', 'value': 420}, {'name': 'tJapaneseTransliterate', 'value': 421}, {'name': 'tLastRegexlibExpressions', 'value': 422}, {'name': 'tLoqateAddressRow', 'value': 423}, {'name': 'tMatchGroup', 'value': 424}, {'name': 'tMatchIndex', 'value': 425}, {'name': 'tMatchIndexPredict', 'value': 426}, {'name': 'tMatchModel', 'value': 427}, {'name': 'tMatchPairing', 'value': 428}, {'name': 'tMatchPredict', 'value': 429}, {'name': 'tMelissaDataAddress', 'value': 430}, {'name': 'tMSSqlInvalidRows', 'value': 431}, {'name': 'tMSSqlValidRows', 'value': 432}, {'name': 'tMultiPatternCheck', 'value': 433}, {'name': 'tMySQLInvalidRows', 'value': 434}, {'name': 'tMySQLValidRows', 'value': 435}, {'name': 'tOracleInvalidRows', 'value': 436}, {'name': 'tOracleValidRows', 'value': 437}, {'name': 'tPatternCheck', 'value': 438}, {'name': 'tPatternExtract', 'value': 439}, {'name': 'tPatternMasking', 'value': 440}, {'name': 'tPatternUnmasking', 'value': 441}, {'name': 'tPersonator', 'value': 442}, {'name': 'tPostgresqlInvalidRows', 'value': 443}, {'name': 'tPostgresqlValidRows', 'value': 444}, {'name': 'tQASAddressRow', 'value': 445}, {'name': 'tQASBatchAddressRow', 'value': 446}, {'name': 'tRecordMatching', 'value': 447}, {'name': 'tReplaceList', 'value': 448}, {'name': 'tReservoirSampling', 'value': 449}, {'name': 'tRuleSurvivorship', 'value': 450}, {'name': 'tSchemaComplianceCheck', 'value': 451}, {'name': 'tStandardizePhoneNumber', 'value': 452}, {'name': 'tStandardizeRow', 'value': 453}, {'name': 'tStem', 'value': 454}, {'name': 'tSurviveFields', 'value': 455}, {'name': 'tSynonymOutput', 'value': 456}, {'name': 'tSynonymSearch', 'value': 457}, {'name': 'tThresholdViolationAlert', 'value': 458}, {'name': 'tTransliterate', 'value': 459}, {'name': 'tUniqRow', 'value': 460}, {'name': 'tUniservBTGeneric', 'value': 461}, {'name': 'tUniservRTConvertName', 'value': 462}, {'name': 'tUniservRTMailBulk', 'value': 463}, {'name': 'tUniservRTMailOutput', 'value': 464}, {'name': 'tUniservRTMailSearch', 'value': 465}, {'name': 'tUniservRTPost', 'value': 466}, {'name': 'tVerifyEmail', 'value': 467}]
# 	 468 Databases tAccessBulkExec
# 	 469 Databases tAccessClose
# 	 470 Databases tAccessCommit
# 	 471 Databases tAccessConnection
# 	 472 Databases tAccessInput
# 	 473 Databases tAccessOutput
# 	 474 Databases tAccessOutputBulk
# 	 475 Databases tAccessOutputBulkExec
# 	 476 Databases tAccessRollback
# 	 477 Databases tAccessRow
# 	 478 Databases tAmazonAuroraClose
# 	 479 Databases tAmazonAuroraCommit
# 	 480 Databases tAmazonAuroraConnection
# 	 481 Databases tAmazonAuroraInput
# 	 482 Databases tAmazonAuroraOutput
# 	 483 Databases tAmazonAuroraRollback
# 	 484 Databases tAmazonMysqlClose
# 	 485 Databases tAmazonMysqlCommit
# 	 486 Databases tAmazonMysqlConnection
# 	 487 Databases tAmazonMysqlInput
# 	 488 Databases tAmazonMysqlOutput
# 	 489 Databases tAmazonMysqlRollback
# 	 490 Databases tAmazonMysqlRow
# 	 491 Databases tAmazonOracleClose
# 	 492 Databases tAmazonOracleCommit
# 	 493 Databases tAmazonOracleConnection
# 	 494 Databases tAmazonOracleInput
# 	 495 Databases tAmazonOracleOutput
# 	 496 Databases tAmazonOracleRollback
# 	 497 Databases tAmazonOracleRow
# 	 498 Databases tAmazonRedshiftManage
# 	 499 Databases tAS400CDC
# 	 500 Databases tAS400Close
# 	 501 Databases tAS400Commit
# 	 502 Databases tAS400Connection
# 	 503 Databases tAS400Input
# 	 504 Databases tAS400LastInsertId
# 	 505 Databases tAS400Output
# 	 506 Databases tAS400Rollback
# 	 507 Databases tAS400Row
# 	 508 Databases tBigQueryConfiguration
# 	 509 Databases tBigQueryInput
# 	 510 Databases tBigQueryOutput
# 	 511 Databases tCassandraConfiguration
# 	 512 Databases tCassandraInput
# 	 513 Databases tCassandraLookupInput
# 	 514 Databases tCassandraOutput
# 	 515 Databases tCosmosDBBulkLoad
# 	 516 Databases tCosmosDBConnection
# 	 517 Databases tCosmosDBInput
# 	 518 Databases tCosmosDBOutput
# 	 519 Databases tCosmosDBRow
# 	 520 Databases tCreateTable
# 	 521 Databases tDB2BulkExec
# 	 522 Databases tDB2CDC
# 	 523 Databases tDB2Close
# 	 524 Databases tDB2Commit
# 	 525 Databases tDB2Connection
# 	 526 Databases tDB2Input
# 	 527 Databases tDB2Output
# 	 528 Databases tDB2Rollback
# 	 529 Databases tDB2Row
# 	 530 Databases tDB2SCD
# 	 531 Databases tDB2SCDELT
# 	 532 Databases tDB2SP
# 	 533 Databases tDBBulkExec
# 	 534 Databases tDBCDC
# 	 535 Databases tDBCDCOutput
# 	 536 Databases tDBClose
# 	 537 Databases tDBColumnList
# 	 538 Databases tDBCommit
# 	 539 Databases tDBConnection
# 	 540 Databases tDBInput
# 	 541 Databases tDBInvalidRows
# 	 542 Databases tDBLastInsertId
# 	 543 Databases tDBOutput
# 	 544 Databases tDBOutputBulk
# 	 545 Databases tDBOutputBulkExec
# 	 546 Databases tDBRollback
# 	 547 Databases tDBRow
# 	 548 Databases tDBSCD
# 	 549 Databases tDBSCDELT
# 	 550 Databases tDBSP
# 	 551 Databases tDBSQLRow
# 	 552 Databases tDBTableList
# 	 553 Databases tDBValidRows
# 	 554 Databases tDynamoDBConfiguration
# 	 555 Databases tDynamoDBInput
# 	 556 Databases tDynamoDBLookupInput
# 	 557 Databases tDynamoDBOutput
# 	 558 Databases tEXABulkExec
# 	 559 Databases tEXAClose
# 	 560 Databases tEXACommit
# 	 561 Databases tEXAConnection
# 	 562 Databases tEXAInput
# 	 563 Databases tEXAOutput
# 	 564 Databases tEXARollback
# 	 565 Databases tEXARow
# 	 566 Databases tEXistConnection
# 	 567 Databases tEXistDelete
# 	 568 Databases tEXistGet
# 	 569 Databases tEXistList
# 	 570 Databases tEXistPut
# 	 571 Databases tEXistXQuery
# 	 572 Databases tEXistXUpdate
# 	 573 Databases tFirebirdClose
# 	 574 Databases tFirebirdCommit
# 	 575 Databases tFirebirdConnection
# 	 576 Databases tFirebirdInput
# 	 577 Databases tFirebirdOutput
# 	 578 Databases tFirebirdRollback
# 	 579 Databases tFirebirdRow
# 	 580 Databases tGreenplumBulkExec
# 	 581 Databases tGreenplumClose
# 	 582 Databases tGreenplumCommit
# 	 583 Databases tGreenplumConnection
# 	 584 Databases tGreenplumGPLoad
# 	 585 Databases tGreenplumInput
# 	 586 Databases tGreenplumOutput
# 	 587 Databases tGreenplumOutputBulk
# 	 588 Databases tGreenplumOutputBulkExec
# 	 589 Databases tGreenplumRollback
# 	 590 Databases tGreenplumRow
# 	 591 Databases tGreenplumSCD
# 	 592 Databases tHBaseConfiguration
# 	 593 Databases tHBaseInput
# 	 594 Databases tHBaseLookupInput
# 	 595 Databases tHBaseOutput
# 	 596 Databases tHiveClose
# 	 597 Databases tHiveConnection
# 	 598 Databases tHiveCreateTable
# 	 599 Databases tHiveInput
# 	 600 Databases tHiveLoad
# 	 601 Databases tHiveOutput
# 	 602 Databases tHiveRow
# 	 603 Databases tHSQLDbInput
# 	 604 Databases tHSQLDbOutput
# 	 605 Databases tHSQLDbRow
# 	 606 Databases tInformixBulkExec
# 	 607 Databases tInformixCDC
# 	 608 Databases tInformixClose
# 	 609 Databases tInformixCommit
# 	 610 Databases tInformixConnection
# 	 611 Databases tInformixInput
# 	 612 Databases tInformixOutput
# 	 613 Databases tInformixOutputBulk
# 	 614 Databases tInformixOutputBulkExec
# 	 615 Databases tInformixRollback
# 	 616 Databases tInformixRow
# 	 617 Databases tInformixSCD
# 	 618 Databases tInformixSP
# 	 619 Databases tIngresBulkExec
# 	 620 Databases tIngresCDC
# 	 621 Databases tIngresClose
# 	 622 Databases tIngresCommit
# 	 623 Databases tIngresConnection
# 	 624 Databases tIngresInput
# 	 625 Databases tIngresOutput
# 	 626 Databases tIngresOutputBulk
# 	 627 Databases tIngresOutputBulkExec
# 	 628 Databases tIngresRollback
# 	 629 Databases tIngresRow
# 	 630 Databases tIngresSCD
# 	 631 Databases tInterbaseClose
# 	 632 Databases tInterbaseCommit
# 	 633 Databases tInterbaseConnection
# 	 634 Databases tInterbaseInput
# 	 635 Databases tInterbaseOutput
# 	 636 Databases tInterbaseRollback
# 	 637 Databases tInterbaseRow
# 	 638 Databases tJavaDBInput
# 	 639 Databases tJavaDBOutput
# 	 640 Databases tJavaDBRow
# 	 641 Databases tJDBCClose
# 	 642 Databases tJDBCColumnList
# 	 643 Databases tJDBCCommit
# 	 644 Databases tJDBCConfiguration
# 	 645 Databases tJDBCConnection
# 	 646 Databases tJDBCInput
# 	 647 Databases tJDBCLookupInput
# 	 648 Databases tJDBCOutput
# 	 649 Databases tJDBCRollback
# 	 650 Databases tJDBCRow
# 	 651 Databases tJDBCSCDELT
# 	 652 Databases tJDBCSP
# 	 653 Databases tJDBCTableList
# 	 654 Databases tKuduConfiguration
# 	 655 Databases tKuduInput
# 	 656 Databases tKuduOutput
# 	 657 Databases tLDAPAttributesInput
# 	 658 Databases tLDAPClose
# 	 659 Databases tLDAPConnection
# 	 660 Databases tLDAPInput
# 	 661 Databases tLDAPOutput
# 	 662 Databases tLDAPRenameEntry
# 	 663 Databases tMapRDBConfiguration
# 	 664 Databases tMapRDBInput
# 	 665 Databases tMapRDBLookupInput
# 	 666 Databases tMapRDBOutput
# 	 667 Databases tMaxDBInput
# 	 668 Databases tMaxDBOutput
# 	 669 Databases tMaxDBRow
# 	 670 Databases tMongoDBConfiguration
# 	 671 Databases tMongoDBInput
# 	 672 Databases tMongoDBLookupInput
# 	 673 Databases tMongoDBOutput
# 	 674 Databases tMSSqlBulkExec
# 	 675 Databases tMSSqlCDC
# 	 676 Databases tMSSqlClose
# 	 677 Databases tMSSqlColumnList
# 	 678 Databases tMSSqlCommit
# 	 679 Databases tMSSqlConnection
# 	 680 Databases tMSSqlInput
# 	 681 Databases tMSSqlLastInsertId
# 	 682 Databases tMSSqlOutput
# 	 683 Databases tMSSqlOutputBulk
# 	 684 Databases tMSSqlOutputBulkExec
# 	 685 Databases tMSSqlRollback
# 	 686 Databases tMSSqlRow
# 	 687 Databases tMSSqlSCD
# 	 688 Databases tMSSqlSP
# 	 689 Databases tMSSqlTableList
# 	 690 Databases tMysqlBulkExec
# 	 691 Databases tMysqlCDC
# 	 692 Databases tMysqlClose
# 	 693 Databases tMysqlColumnList
# 	 694 Databases tMysqlCommit
# 	 695 Databases tMysqlConfiguration
# 	 696 Databases tMysqlConnection
# 	 697 Databases tMysqlInput
# 	 698 Databases tMySQLInvalidRows
# 	 699 Databases tMysqlLastInsertId
# 	 700 Databases tMysqlLookupInput
# 	 701 Databases tMysqlOutput
# 	 702 Databases tMysqlOutputBulk
# 	 703 Databases tMysqlOutputBulkExec
# 	 704 Databases tMysqlRollback
# 	 705 Databases tMysqlRow
# 	 706 Databases tMysqlSCD
# 	 707 Databases tMysqlSCDELT
# 	 708 Databases tMysqlSP
# 	 709 Databases tMysqlTableList
# 	 710 Databases tMySQLValidRows
# 	 711 Databases tNetezzaBulkExec
# 	 712 Databases tNetezzaClose
# 	 713 Databases tNetezzaCommit
# 	 714 Databases tNetezzaConnection
# 	 715 Databases tNetezzaInput
# 	 716 Databases tNetezzaNzLoad
# 	 717 Databases tNetezzaOutput
# 	 718 Databases tNetezzaRollback
# 	 719 Databases tNetezzaRow
# 	 720 Databases tNetezzaSCD
# 	 721 Databases tOracleBulkExec
# 	 722 Databases tOracleCDC
# 	 723 Databases tOracleCDCOutput
# 	 724 Databases tOracleClose
# 	 725 Databases tOracleCommit
# 	 726 Databases tOracleConfiguration
# 	 727 Databases tOracleConnection
# 	 728 Databases tOracleInput
# 	 729 Databases tOracleInvalidRows
# 	 730 Databases tOracleLookupInput
# 	 731 Databases tOracleOutput
# 	 732 Databases tOracleOutputBulk
# 	 733 Databases tOracleOutputBulkExec
# 	 734 Databases tOracleRollback
# 	 735 Databases tOracleRow
# 	 736 Databases tOracleSCD
# 	 737 Databases tOracleSCDELT
# 	 738 Databases tOracleSP
# 	 739 Databases tOracleTableList
# 	 740 Databases tOracleValidRows
# 	 741 Databases tParAccelBulkExec
# 	 742 Databases tParAccelClose
# 	 743 Databases tParAccelCommit
# 	 744 Databases tParAccelConnection
# 	 745 Databases tParAccelInput
# 	 746 Databases tParAccelOutput
# 	 747 Databases tParAccelOutputBulk
# 	 748 Databases tParAccelOutputBulkExec
# 	 749 Databases tParAccelRollback
# 	 750 Databases tParAccelRow
# 	 751 Databases tParAccelSCD
# 	 752 Databases tParseRecordSet
# 	 753 Databases tPostgresPlusBulkExec
# 	 754 Databases tPostgresPlusClose
# 	 755 Databases tPostgresPlusCommit
# 	 756 Databases tPostgresPlusConnection
# 	 757 Databases tPostgresPlusInput
# 	 758 Databases tPostgresPlusOutput
# 	 759 Databases tPostgresPlusOutputBulk
# 	 760 Databases tPostgresPlusOutputBulkExec
# 	 761 Databases tPostgresPlusRollback
# 	 762 Databases tPostgresPlusRow
# 	 763 Databases tPostgresPlusSCD
# 	 764 Databases tPostgresPlusSCDELT
# 	 765 Databases tPostgresqlBulkExec
# 	 766 Databases tPostgresqlCDC
# 	 767 Databases tPostgresqlClose
# 	 768 Databases tPostgresqlCommit
# 	 769 Databases tPostgresqlConnection
# 	 770 Databases tPostgresqlInput
# 	 771 Databases tPostgresqlInvalidRows
# 	 772 Databases tPostgresqlOutput
# 	 773 Databases tPostgresqlOutputBulk
# 	 774 Databases tPostgresqlOutputBulkExec
# 	 775 Databases tPostgresqlRollback
# 	 776 Databases tPostgresqlRow
# 	 777 Databases tPostgresqlSCD
# 	 778 Databases tPostgresqlSCDELT
# 	 779 Databases tPostgresqlValidRows
# 	 780 Databases tRedshiftBulkExec
# 	 781 Databases tRedshiftClose
# 	 782 Databases tRedshiftCommit
# 	 783 Databases tRedshiftConfiguration
# 	 784 Databases tRedshiftConnection
# 	 785 Databases tRedshiftInput
# 	 786 Databases tRedshiftLookupInput
# 	 787 Databases tRedshiftOutput
# 	 788 Databases tRedshiftOutputBulk
# 	 789 Databases tRedshiftOutputBulkExec
# 	 790 Databases tRedshiftRollback
# 	 791 Databases tRedshiftRow
# 	 792 Databases tRedshiftUnload
# 	 793 Databases tSAPHanaClose
# 	 794 Databases tSAPHanaCommit
# 	 795 Databases tSAPHanaConnection
# 	 796 Databases tSAPHanaInput
# 	 797 Databases tSAPHanaOutput
# 	 798 Databases tSAPHanaRollback
# 	 799 Databases tSAPHanaRow
# 	 800 Databases tSAPHanaUnload
# 	 801 Databases tSnowflakeConfiguration
# 	 802 Databases tSnowflakeInput
# 	 803 Databases tSnowflakeOutput
# 	 804 Databases tSQLDWHBulkExec
# 	 805 Databases tSQLDWHClose
# 	 806 Databases tSQLDWHCommit
# 	 807 Databases tSQLDWHConnection
# 	 808 Databases tSQLDWHInput
# 	 809 Databases tSQLDWHOutput
# 	 810 Databases tSQLDWHRollback
# 	 811 Databases tSQLDWHRow
# 	 812 Databases tSQLiteClose
# 	 813 Databases tSQLiteCommit
# 	 814 Databases tSQLiteConnection
# 	 815 Databases tSQLiteInput
# 	 816 Databases tSQLiteOutput
# 	 817 Databases tSQLiteRollback
# 	 818 Databases tSQLiteRow
# 	 819 Databases tSybaseBulkExec
# 	 820 Databases tSybaseCDC
# 	 821 Databases tSybaseClose
# 	 822 Databases tSybaseCommit
# 	 823 Databases tSybaseConnection
# 	 824 Databases tSybaseInput
# 	 825 Databases tSybaseIQBulkExec
# 	 826 Databases tSybaseIQOutputBulkExec
# 	 827 Databases tSybaseOutput
# 	 828 Databases tSybaseOutputBulk
# 	 829 Databases tSybaseOutputBulkExec
# 	 830 Databases tSybaseRollback
# 	 831 Databases tSybaseRow
# 	 832 Databases tSybaseSCD
# 	 833 Databases tSybaseSCDELT
# 	 834 Databases tSybaseSP
# 	 835 Databases tTeradataCDC
# 	 836 Databases tTeradataClose
# 	 837 Databases tTeradataCommit
# 	 838 Databases tTeradataConfiguration
# 	 839 Databases tTeradataConnection
# 	 840 Databases tTeradataFastExport
# 	 841 Databases tTeradataFastLoad
# 	 842 Databases tTeradataFastLoadUtility
# 	 843 Databases tTeradataInput
# 	 844 Databases tTeradataLookupInput
# 	 845 Databases tTeradataMultiLoad
# 	 846 Databases tTeradataOutput
# 	 847 Databases tTeradataRollback
# 	 848 Databases tTeradataRow
# 	 849 Databases tTeradataSCD
# 	 850 Databases tTeradataSCDELT
# 	 851 Databases tTeradataTPTExec
# 	 852 Databases tTeradataTPTUtility
# 	 853 Databases tTeradataTPump
# 	 854 Databases tVectorWiseCommit
# 	 855 Databases tVectorWiseConnection
# 	 856 Databases tVectorWiseInput
# 	 857 Databases tVectorWiseOutput
# 	 858 Databases tVectorWiseRollback
# 	 859 Databases tVectorWiseRow
# 	 860 Databases tVerticaBulkExec
# 	 861 Databases tVerticaClose
# 	 862 Databases tVerticaCommit
# 	 863 Databases tVerticaConnection
# 	 864 Databases tVerticaInput
# 	 865 Databases tVerticaOutput
# 	 866 Databases tVerticaOutputBulk
# 	 867 Databases tVerticaOutputBulkExec
# 	 868 Databases tVerticaRollback
# 	 869 Databases tVerticaRow
# 	 870 Databases tVerticaSCD
# ...
# 	 1189 MapReduce tFileInputXML
# 	 1190 MapReduce tFileOutputDelimited
# 	 1191 MapReduce tFileOutputJSON
# 	 1192 MapReduce tFileOutputParquet
# 	 1193 MapReduce tFileOutputPositional
# 	 1194 MapReduce tFileOutputXML
# 	 1195 MapReduce tGlobalVarLoad
# 	 1196 MapReduce tHBaseInput
# 	 1197 MapReduce tHBaseOutput
# 	 1198 MapReduce tHDFSInput
# 	 1199 MapReduce tHDFSOutput
# 	 1200 MapReduce tJDBCInput
# 	 1201 MapReduce tJDBCOutput
# 	 1202 MapReduce tMahoutClustering
# 	 1203 MapReduce tMapRDBInput
# 	 1204 MapReduce tMapRDBOutput
# 	 1205 MapReduce tS3Input
# 	 1206 MapReduce tS3Output
# Components List Messaging :: [{'name': 'tAvroInput', 'value': 1182}, {'name': 'tAvroOutput', 'value': 1183}, {'name': 'tFileInputDelimited', 'value': 1184}, {'name': 'tFileInputFullRow', 'value': 1185}, {'name': 'tFileInputJSON', 'value': 1186}, {'name': 'tFileInputParquet', 'value': 1187}, {'name': 'tFileInputPositional', 'value': 1188}, {'name': 'tFileInputXML', 'value': 1189}, {'name': 'tFileOutputDelimited', 'value': 1190}, {'name': 'tFileOutputJSON', 'value': 1191}, {'name': 'tFileOutputParquet', 'value': 1192}, {'name': 'tFileOutputPositional', 'value': 1193}, {'name': 'tFileOutputXML', 'value': 1194}, {'name': 'tGlobalVarLoad', 'value': 1195}, {'name': 'tHBaseInput', 'value': 1196}, {'name': 'tHBaseOutput', 'value': 1197}, {'name': 'tHDFSInput', 'value': 1198}, {'name': 'tHDFSOutput', 'value': 1199}, {'name': 'tJDBCInput', 'value': 1200}, {'name': 'tJDBCOutput', 'value': 1201}, {'name': 'tMahoutClustering', 'value': 1202}, {'name': 'tMapRDBInput', 'value': 1203}, {'name': 'tMapRDBOutput', 'value': 1204}, {'name': 'tS3Input', 'value': 1205}, {'name': 'tS3Output', 'value': 1206}]
# 	 1207 Messaging tFlumeInput
# 	 1208 Messaging tFlumeOutput
# 	 1209 Messaging tJMSInput
# 	 1210 Messaging tJMSOutput
# 	 1211 Messaging tKafkaInput
# 	 1212 Messaging tKafkaInputAvro
# 	 1213 Messaging tKafkaOutput
# 	 1214 Messaging tKinesisInput
# 	 1215 Messaging tKinesisInputAvro
# 	 1216 Messaging tKinesisOutput
# 	 1217 Messaging tMapRStreamsInput
# 	 1218 Messaging tMapRStreamsInputAvro
# 	 1219 Messaging tMapRStreamsOutput
# 	 1220 Messaging tMQTTInput
# 	 1221 Messaging tMQTTOutput
# 	 1222 Messaging tPubSubInput
# 	 1223 Messaging tPubSubInputAvro
# 	 1224 Messaging tPubSubOutput
# Components List Misc :: [{'name': 'tFlumeInput', 'value': 1207}, {'name': 'tFlumeOutput', 'value': 1208}, {'name': 'tJMSInput', 'value': 1209}, {'name': 'tJMSOutput', 'value': 1210}, {'name': 'tKafkaInput', 'value': 1211}, {'name': 'tKafkaInputAvro', 'value': 1212}, {'name': 'tKafkaOutput', 'value': 1213}, {'name': 'tKinesisInput', 'value': 1214}, {'name': 'tKinesisInputAvro', 'value': 1215}, {'name': 'tKinesisOutput', 'value': 1216}, {'name': 'tMapRStreamsInput', 'value': 1217}, {'name': 'tMapRStreamsInputAvro', 'value': 1218}, {'name': 'tMapRStreamsOutput', 'value': 1219}, {'name': 'tMQTTInput', 'value': 1220}, {'name': 'tMQTTOutput', 'value': 1221}, {'name': 'tPubSubInput', 'value': 1222}, {'name': 'tPubSubInputAvro', 'value': 1223}, {'name': 'tPubSubOutput', 'value': 1224}]
# 	 1225 Misc tAddLocationFromIP
# 	 1226 Misc tBufferInput
# 	 1227 Misc tBufferOutput
# 	 1228 Misc tContextDump
# 	 1229 Misc tContextLoad
# 	 1230 Misc tFixedFlowInput
# 	 1231 Misc tLogRow
# 	 1232 Misc tMemorizeRows
# 	 1233 Misc tMsgBox
# 	 1234 Misc tRowGenerator
# 	 1235 Misc tServerAlive
# Components List Miscellaneous :: [{'name': 'tAddLocationFromIP', 'value': 1225}, {'name': 'tBufferInput', 'value': 1226}, {'name': 'tBufferOutput', 'value': 1227}, {'name': 'tContextDump', 'value': 1228}, {'name': 'tContextLoad', 'value': 1229}, {'name': 'tFixedFlowInput', 'value': 1230}, {'name': 'tLogRow', 'value': 1231}, {'name': 'tMemorizeRows', 'value': 1232}, {'name': 'tMsgBox', 'value': 1233}, {'name': 'tRowGenerator', 'value': 1234}, {'name': 'tServerAlive', 'value': 1235}]
# 	 1236 Miscellaneous cLog
# 	 1237 Miscellaneous cStop
# Components List Natural Language Processing :: [{'name': 'cLog', 'value': 1236}, {'name': 'cStop', 'value': 1237}]
# 	 1238 Natural Language Processing tCompareColumns
# 	 1239 Natural Language Processing tNLPModel
# 	 1240 Natural Language Processing tNLPPredict
# 	 1241 Natural Language Processing tNLPPreprocessing
# Components List Orchestration :: [{'name': 'tCompareColumns', 'value': 1238}, {'name': 'tNLPModel', 'value': 1239}, {'name': 'tNLPPredict', 'value': 1240}, {'name': 'tNLPPreprocessing', 'value': 1241}]
# 	 1242 Orchestration cDelayer
# 	 1243 Orchestration cLoop
# 	 1244 Orchestration cTimer
# 	 1245 Orchestration tCollector
# 	 1246 Orchestration tDepartitioner
# 	 1247 Orchestration tFileList
# 	 1248 Orchestration tFlowToIterate
# 	 1249 Orchestration tForeach
# 	 1250 Orchestration tInfiniteLoop
# 	 1251 Orchestration tIterateToFlow
# 	 1252 Orchestration tLoop
# 	 1253 Orchestration tParallelize
# 	 1254 Orchestration tPartitioner
# 	 1255 Orchestration tPostjob
# 	 1256 Orchestration tPrejob
# 	 1257 Orchestration tRecollector
# 	 1258 Orchestration tReplicate
# 	 1259 Orchestration tRunJob
# 	 1260 Orchestration tSleep
# 	 1261 Orchestration tUnite
# 	 1262 Orchestration tWaitForFile
# 	 1263 Orchestration tWaitForSocket
# 	 1264 Orchestration tWaitForSqlData
# Components List Processing :: [{'name': 'cDelayer', 'value': 1242}, {'name': 'cLoop', 'value': 1243}, {'name': 'cTimer', 'value': 1244}, {'name': 'tCollector', 'value': 1245}, {'name': 'tDepartitioner', 'value': 1246}, {'name': 'tFileList', 'value': 1247}, {'name': 'tFlowToIterate', 'value': 1248}, {'name': 'tForeach', 'value': 1249}, {'name': 'tInfiniteLoop', 'value': 1250}, {'name': 'tIterateToFlow', 'value': 1251}, {'name': 'tLoop', 'value': 1252}, {'name': 'tParallelize', 'value': 1253}, {'name': 'tPartitioner', 'value': 1254}, {'name': 'tPostjob', 'value': 1255}, {'name': 'tPrejob', 'value': 1256}, {'name': 'tRecollector', 'value': 1257}, {'name': 'tReplicate', 'value': 1258}, {'name': 'tRunJob', 'value': 1259}, {'name': 'tSleep', 'value': 1260}, {'name': 'tUnite', 'value': 1261}, {'name': 'tWaitForFile', 'value': 1262}, {'name': 'tWaitForSocket', 'value': 1263}, {'name': 'tWaitForSqlData', 'value': 1264}]
# 	 1265 Processing tAggregateRow
# 	 1266 Processing tAggregateSortedRow
# 	 1267 Processing tBRMS
# 	 1268 Processing tCacheIn
# 	 1269 Processing tCacheOut
# 	 1270 Processing tConvertType
# 	 1271 Processing tDenormalize
# 	 1272 Processing tDenormalizeSortedRow
# 	 1273 Processing tExternalSortRow
# 	 1274 Processing tExtractDelimitedFields
# 	 1275 Processing tExtractDynamicFields
# 	 1276 Processing tExtractEDIField
# 	 1277 Processing tExtractJSONFields
# 	 1278 Processing tExtractPositionalFields
# 	 1279 Processing tExtractRegexFields
# 	 1280 Processing tExtractXMLField
# 	 1281 Processing tFilterColumns
# 	 1282 Processing tFilterRow
# 	 1283 Processing tHConvertFile
# 	 1284 Processing tHMap
# 	 1285 Processing tHMapFile
# 	 1286 Processing tHMapInput
# 	 1287 Processing tHMapRecord
# 	 1288 Processing tJoin
# 	 1289 Processing tMap
# 	 1290 Processing tNormalize
# 	 1291 Processing tPartition
# 	 1292 Processing tReplace
# 	 1293 Processing tReplicate
# 	 1294 Processing tRules
# 	 1295 Processing tSample
# 	 1296 Processing tSampleRow
# 	 1297 Processing tSortRow
# 	 1298 Processing tSplitRow
# 	 1299 Processing tSqlRow
# 	 1300 Processing tSurviveFields
# 	 1301 Processing tTop
# 	 1302 Processing tTopBy
# 	 1303 Processing tUniqRow
# 	 1304 Processing tWindow
# 	 1305 Processing tWriteAvroFields
# 	 1306 Processing tWriteDelimitedFields
# 	 1307 Processing tWriteDynamicFields
# 	 1308 Processing tWriteJSONField
# 	 1309 Processing tWritePositionalFields
# 	 1310 Processing tWriteXMLFields
# 	 1311 Processing tXMLMap
# Components List Routing :: [{'name': 'tAggregateRow', 'value': 1265}, {'name': 'tAggregateSortedRow', 'value': 1266}, {'name': 'tBRMS', 'value': 1267}, {'name': 'tCacheIn', 'value': 1268}, {'name': 'tCacheOut', 'value': 1269}, {'name': 'tConvertType', 'value': 1270}, {'name': 'tDenormalize', 'value': 1271}, {'name': 'tDenormalizeSortedRow', 'value': 1272}, {'name': 'tExternalSortRow', 'value': 1273}, {'name': 'tExtractDelimitedFields', 'value': 1274}, {'name': 'tExtractDynamicFields', 'value': 1275}, {'name': 'tExtractEDIField', 'value': 1276}, {'name': 'tExtractJSONFields', 'value': 1277}, {'name': 'tExtractPositionalFields', 'value': 1278}, {'name': 'tExtractRegexFields', 'value': 1279}, {'name': 'tExtractXMLField', 'value': 1280}, {'name': 'tFilterColumns', 'value': 1281}, {'name': 'tFilterRow', 'value': 1282}, {'name': 'tHConvertFile', 'value': 1283}, {'name': 'tHMap', 'value': 1284}, {'name': 'tHMapFile', 'value': 1285}, {'name': 'tHMapInput', 'value': 1286}, {'name': 'tHMapRecord', 'value': 1287}, {'name': 'tJoin', 'value': 1288}, {'name': 'tMap', 'value': 1289}, {'name': 'tNormalize', 'value': 1290}, {'name': 'tPartition', 'value': 1291}, {'name': 'tReplace', 'value': 1292}, {'name': 'tReplicate', 'value': 1293}, {'name': 'tRules', 'value': 1294}, {'name': 'tSample', 'value': 1295}, {'name': 'tSampleRow', 'value': 1296}, {'name': 'tSortRow', 'value': 1297}, {'name': 'tSplitRow', 'value': 1298}, {'name': 'tSqlRow', 'value': 1299}, {'name': 'tSurviveFields', 'value': 1300}, {'name': 'tTop', 'value': 1301}, {'name': 'tTopBy', 'value': 1302}, {'name': 'tUniqRow', 'value': 1303}, {'name': 'tWindow', 'value': 1304}, {'name': 'tWriteAvroFields', 'value': 1305}, {'name': 'tWriteDelimitedFields', 'value': 1306}, {'name': 'tWriteDynamicFields', 'value': 1307}, {'name': 'tWriteJSONField', 'value': 1308}, {'name': 'tWritePositionalFields', 'value': 1309}, {'name': 'tWriteXMLFields', 'value': 1310}, {'name': 'tXMLMap', 'value': 1311}]
# 	 1312 Routing cAggregate
# 	 1313 Routing cDynamicRouter
# 	 1314 Routing cIdempotentConsumer
# 	 1315 Routing cLoadBalancer
# 	 1316 Routing cMessageFilter
# 	 1317 Routing cMessageRouter
# 	 1318 Routing cMulticast
# 	 1319 Routing cPipesAndFilters
# 	 1320 Routing cRecipientList
# 	 1321 Routing cRoutingSlip
# 	 1322 Routing cSplitter
# 	 1323 Routing cThrottler
# 	 1324 Routing cWireTap
# Components List Storage :: [{'name': 'cAggregate', 'value': 1312}, {'name': 'cDynamicRouter', 'value': 1313}, {'name': 'cIdempotentConsumer', 'value': 1314}, {'name': 'cLoadBalancer', 'value': 1315}, {'name': 'cMessageFilter', 'value': 1316}, {'name': 'cMessageRouter', 'value': 1317}, {'name': 'cMulticast', 'value': 1318}, {'name': 'cPipesAndFilters', 'value': 1319}, {'name': 'cRecipientList', 'value': 1320}, {'name': 'cRoutingSlip', 'value': 1321}, {'name': 'cSplitter', 'value': 1322}, {'name': 'cThrottler', 'value': 1323}, {'name': 'cWireTap', 'value': 1324}]
# 	 1325 Storage tAzureFSConfiguration
# 	 1326 Storage tBigQueryConfiguration
# 	 1327 Storage tCassandraConfiguration
# 	 1328 Storage tDynamoDBConfiguration
# 	 1329 Storage tGoogleCloudConfiguration
# 	 1330 Storage tGSConfiguration
# 	 1331 Storage tHBaseConfiguration
# 	 1332 Storage tHDFSConfiguration
# 	 1333 Storage tHiveConfiguration
# 	 1334 Storage tJDBCConfiguration
# 	 1335 Storage tKuduConfiguration
# 	 1336 Storage tMapRDBConfiguration
# 	 1337 Storage tMysqlConfiguration
# 	 1338 Storage tOracleConfiguration
# 	 1339 Storage tRedshiftConfiguration
# 	 1340 Storage tS3Configuration
# 	 1341 Storage tTachyonConfiguration
# 	 1342 Storage tTeradataConfiguration
# Components List Storm :: [{'name': 'tAzureFSConfiguration', 'value': 1325}, {'name': 'tBigQueryConfiguration', 'value': 1326}, {'name': 'tCassandraConfiguration', 'value': 1327}, {'name': 'tDynamoDBConfiguration', 'value': 1328}, {'name': 'tGoogleCloudConfiguration', 'value': 1329}, {'name': 'tGSConfiguration', 'value': 1330}, {'name': 'tHBaseConfiguration', 'value': 1331}, {'name': 'tHDFSConfiguration', 'value': 1332}, {'name': 'tHiveConfiguration', 'value': 1333}, {'name': 'tJDBCConfiguration', 'value': 1334}, {'name': 'tKuduConfiguration', 'value': 1335}, {'name': 'tMapRDBConfiguration', 'value': 1336}, {'name': 'tMysqlConfiguration', 'value': 1337}, {'name': 'tOracleConfiguration', 'value': 1338}, {'name': 'tRedshiftConfiguration', 'value': 1339}, {'name': 'tS3Configuration', 'value': 1340}, {'name': 'tTachyonConfiguration', 'value': 1341}, {'name': 'tTeradataConfiguration', 'value': 1342}]
# 	 1343 Storm tJDBCOutput
# Components List System :: [{'name': 'tJDBCOutput', 'value': 1343}]
# 	 1344 System tRunJob
# 	 1345 System tSetEnv
# 	 1346 System tSSH
# 	 1347 System tSystem
# Components List Talend :: [{'name': 'tRunJob', 'value': 1344}, {'name': 'tSetEnv', 'value': 1345}, {'name': 'tSSH', 'value': 1346}, {'name': 'tSystem', 'value': 1347}]
# 	 1348 Talend cTalendJob
# Components List Talend Cloud :: [{'name': 'cTalendJob', 'value': 1348}]
# 	 1349 Talend Cloud tJobFailure
# 	 1350 Talend Cloud tJobLog
# 	 1351 Talend Cloud tJobReject
# Components List Talend Data Preparation :: [{'name': 'tJobFailure', 'value': 1349}, {'name': 'tJobLog', 'value': 1350}, {'name': 'tJobReject', 'value': 1351}]
# 	 1352 Talend Data Preparation tDataprepRun
# 	 1353 Talend Data Preparation tDatasetInput
# 	 1354 Talend Data Preparation tDatasetOutput
# Components List Talend Data Stewardship :: [{'name': 'tDataprepRun', 'value': 1352}, {'name': 'tDatasetInput', 'value': 1353}, {'name': 'tDatasetOutput', 'value': 1354}]
# 	 1355 Talend Data Stewardship tDataStewardshipTaskDelete
# 	 1356 Talend Data Stewardship tDataStewardshipTaskInput
# 	 1357 Talend Data Stewardship tDataStewardshipTaskOutput
# Components List Talend MDM :: [{'name': 'tDataStewardshipTaskDelete', 'value': 1355}, {'name': 'tDataStewardshipTaskInput', 'value': 1356}, {'name': 'tDataStewardshipTaskOutput', 'value': 1357}]
# 	 1358 Talend MDM tMDMBulkLoad
# 	 1359 Talend MDM tMDMClose
# 	 1360 Talend MDM tMDMCommit
# 	 1361 Talend MDM tMDMConnection
# 	 1362 Talend MDM tMDMDelete
# 	 1363 Talend MDM tMDMInput
# 	 1364 Talend MDM tMDMOutput
# 	 1365 Talend MDM tMDMReceive
# 	 1366 Talend MDM tMDMRestInput
# 	 1367 Talend MDM tMDMRollback
# 	 1368 Talend MDM tMDMRouteRecord
# 	 1369 Talend MDM tMDMSP
# 	 1370 Talend MDM tMDMTriggerInput
# 	 1371 Talend MDM tMDMTriggerOutput
# 	 1372 Talend MDM tMDMViewSearch
# 	 1373 Talend MDM tSurviveFields
# Components List Technical :: [{'name': 'tMDMBulkLoad', 'value': 1358}, {'name': 'tMDMClose', 'value': 1359}, {'name': 'tMDMCommit', 'value': 1360}, {'name': 'tMDMConnection', 'value': 1361}, {'name': 'tMDMDelete', 'value': 1362}, {'name': 'tMDMInput', 'value': 1363}, {'name': 'tMDMOutput', 'value': 1364}, {'name': 'tMDMReceive', 'value': 1365}, {'name': 'tMDMRestInput', 'value': 1366}, {'name': 'tMDMRollback', 'value': 1367}, {'name': 'tMDMRouteRecord', 'value': 1368}, {'name': 'tMDMSP', 'value': 1369}, {'name': 'tMDMTriggerInput', 'value': 1370}, {'name': 'tMDMTriggerOutput', 'value': 1371}, {'name': 'tMDMViewSearch', 'value': 1372}, {'name': 'tSurviveFields', 'value': 1373}]
# 	 1374 Technical tBoundedStreamInput
# 	 1375 Technical tCollectAndCheck
# 	 1376 Technical tDeltaLakeInput
# 	 1377 Technical tDeltaLakeOutput
# 	 1378 Technical tHashInput
# 	 1379 Technical tHashOutput
# Components List Testing :: [{'name': 'tBoundedStreamInput', 'value': 1374}, {'name': 'tCollectAndCheck', 'value': 1375}, {'name': 'tDeltaLakeInput', 'value': 1376}, {'name': 'tDeltaLakeOutput', 'value': 1377}, {'name': 'tHashInput', 'value': 1378}, {'name': 'tHashOutput', 'value': 1379}]
# 	 1380 Testing cDataset
# 	 1381 Testing cMock
# Components List Transformation :: [{'name': 'cDataset', 'value': 1380}, {'name': 'cMock', 'value': 1381}]
# 	 1382 Transformation cContentEnricher
# 	 1383 Transformation cConvertBodyTo
# 	 1384 Transformation cFlatPack
# 	 1385 Transformation cMap
# Components List Webservice :: [{'name': 'cContentEnricher', 'value': 1382}, {'name': 'cConvertBodyTo', 'value': 1383}, {'name': 'cFlatPack', 'value': 1384}, {'name': 'cMap', 'value': 1385}]
# 	 1386 Webservice tRestWebServiceLookupInput
# 	 1387 Webservice tRestWebServiceOutput
# Components List XML :: [{'name': 'tRestWebServiceLookupInput', 'value': 1386}, {'name': 'tRestWebServiceOutput', 'value': 1387}]
# 	 1388 XML tAdvancedFileOutputXML
# 	 1389 XML tDTDValidator
# 	 1390 XML tEDIFACTtoXML
# 	 1391 XML tExtractXMLField
# 	 1392 XML tFileInputMSXML
# 	 1393 XML tFileInputXML
# 	 1394 XML tFileOutputXML
# 	 1395 XML tWriteXMLField
# 	 1396 XML tXMLMap
# 	 1397 XML tXSDValidator
# 	 1398 XML tXSLT
# Statistics:
#  Number of families:	 43
#  Number of components:	 1399
