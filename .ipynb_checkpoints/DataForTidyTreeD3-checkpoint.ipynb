# %%
#
# This tiny python script scrapes the talendforge.org web site for a list of Talend components and their corresponding
# categories (families) and creates a hierarchy and writes the hierarchy to various json and csv files to be input into a D3 data
# visualization.
# This notebook consists of three parts:
# Cell 1 scrapes the web site and loads the div data structure
# Cell 2 iterates over the divs and extracts component names and the families they belong too
# Pending; not implemented -> Cell 3 unfortunately there are duplicate component names so this cell reads in the component names
#        csv file and de-duplicates the component names file
#
# Data format we want to output:
# Note that only leaf nodes or edge nodes have a value.

#id,value
#flare,
#flare.analytics,
#flare.analytics.cluster,
#flare.analytics.cluster.AgglomerativeCluster,3938
#flare.analytics.cluster.CommunityStructure,3812
#flare.analytics.cluster.HierarchicalCluster,6714
#flare.analytics.cluster.MergeEdge,743
#flare.analytics.graph,
#flare.analytics.graph.BetweennessCentrality,3534
#flare.analytics.graph.LinkDistance,5731
#flare.analytics.graph.MaxFlowMinCut,7840
#flare.analytics.graph.ShortestPaths,5914
#flare.analytics.graph.SpanningTree,3416
#flare.analytics.optimization,
#flare.analytics.optimization.AspectRatioBanker,7074

import os
import requests
from bs4 import BeautifulSoup
import json 

# need these parameters to get correct response from web site
parameters = {
    'version':'255',
    'edition':'13',
    'ALL':'Show All'
}
#
# To find the above parameters:
# Open up Developer Tools in Chrome by selecting View > Developer > Developer Tools.
# Select the Network Tab.
# Visit the page you’re going to do your search from.
# Click the Clear button and then submit your form.
# The Network tab will fill with activity!
# Find the thing in the Network tab that looks like the same name as your webpage. Click it. In this case it was index.php
# On the right-hand side you get a new pane. Scroll down, keep scrolling, yep, all the way down until you see
# Form Data. Those are the parameters I found for version, edition and ALL.
#
# Refer to: http://jonathansoma.com/lede/foundations-2017/classes/adv-scraping/advanced-scraping-form-submission/

# we are doing a post here instead of the usual get because we are scraping a form. It gets trickier if we have to 
# submit headers.
req = requests.post("http://www.talendforge.org/components/index.php", data = parameters)

# If you are going to be testing a lot, then write out the file to be polite to the web server 
# and observe web scraping etiquette. Your mother will love you for it.

# and the magic begins (lxml is the faster parser and recommended by BeautifulSoup. See docs.)
soup = BeautifulSoup(req.content, 'lxml')

# start with all targeted divs, then descend down the hierarchy
# as appropriate. We found out via viewing the source of the web page that we are interested in 
# two classes: "family" (category) and "line_component" (name of the component)
divs = soup.find_all('div', class_=['family','line_component'])

# %%
# Matchlist creates another level or two if there are multiple matches. 
# Examining the data leads us to conclude that the max number of levels is 3 but the data viz shows up to 
# four levels and it gets cut off by the viewport.
def matchparent(input):
    # matchlist was crafted in a manual and iterative fashion based upon looking at the data. The categories
    # are logical albeit contrived. Beware some artifacts may have been introduced but the total number of component
    # names scraped from the web site was not altered or duplicated.
    matchlist = ["Amazon","Cassandra","DynamoDB","HBase","HDFS","Hive","Impala","MapR","MarkLogic",
             "MongoDB","Neo4j","Riak","Sqoop","Marketo","Netsuite","Salesforce","SAP",
             "ServiceNow","MSSql","Netezza","Oracle","Palo","Postgres","Splunk","Sybase",
             "Teradata", "Aurora","Redshift","Azure","Box","Cosmos","Dropbox",
             "Google","S3","Snowflake","Java","Access","EXA","Firebird","Greenplum","Informix",
             "Ingres","Interbase","Kudu","ParAccel","Couchbase","JBoss","Kafka","Microsoft", "Mysql",
             "Vertica", "VectorWise", "SQLite", "SQLDWH", "LDAP", "JDBC", "AS400", "DB2", "HSQLD",
             "EXist", "SQS", "FileInput", "FileOutput", "FileStream", "Uniserve",
             "Match", "Address"]
    list = []
    for item in matchlist:
        if item in input:
            list.append(item)
    
    return list


# family and line_component counters for data viz parameters
i = j = 0
# create main dictionary and initialize top element
data_fabric = []
#data_fabric['id'] = "Talend Data Fabric"
#data_fabric['children'] = []

#
# need to inspect web page to test the following logic (in case web page has changed).
# this logic was driven by the fact that the family div and the div where the component information
# resided were at the same level; no explict parent:child relationship defined but the relationship was 
# implicit based upon position or sequence in the web page so the family category was decoupled from
# the component info.
#
# initialize first family value; this is our trigger to add family and component children to the dictionary
# and start a new list of components
oldfamily = ""
#create dictionaries to store component levels
matches = {}
matchesL2 = {}
#open output file (should check for errors but we are hacking here)
#this is the main data file that is read in for the component tree visualization
f = open("TalendComponentsV8-2023.csv","w+")
    
out = "id, value\nTalend Studio 8,\n"
#out = "id, value\nTalend Data Fabric,\n"
f.write(out)
#print("id, value\nTalend_Data_Fabric,")
#using underscores because D3 / DOM doesn't like spaces (used to be Talend Studio 8)
#parsed and replaced with spaces in Javascript code so they don't show up in the component tree
root = "Talend_Studio_8."
#root = "Talend Data Fabric."
outputString = ""
matchitems = [] # a list of matched items
descriptionList = {}
iconList = {} # added this list to output the entire name of the icon file as some icons are tagged with generic_component
# icon files. Older logic created the filename on the fly and this failed so we output the file name from the scrapage.

# seen is for actual list of component names (de-duped)
seen = []
# loop over all the divs returned from BeautifulSoup's find_all
# remember the family and the component name are at the same level in the DOM so we have to create a hierarchy
for div in divs: #iterate over the divs
    classname = div.get('class',[''])[0] # stolen from stackoverflow 8)
    if classname == 'family':
        family = div.text.strip()
        # family = family.replace(" ", "_") # not sure if D3 can handle spaces. Yep it can.
        if (family != oldfamily): #indicates we are at another family
            oldfamily = family
        outputString = family
        out = root+outputString + ",\n"
        f.write(out)
        # print(root+outputString + ",")
        j+=1 #family counter
    elif classname =='line_component': # edge node
        # this may be overkill but its Sunday morning and I want to finish this
        name = div.find(class_='name').find('a').string.strip()
        if name in seen:
            print("family, duplicate name", family, name)
        else:
            # maintain a list of actual component names for the sake of veracity 8)
            seen.append(name)
        # We are getting the component icon and description for tooltips in our data viz.
        img = div.find('img', src=True)
        #print("img: ", img['src'].split("images/8.0.1/")[1]) #get the icon filename; needs to change if the path is differnent
        iconList[name] = img['src'].split("images/8.0.1/")[1]
        desc = div.find(class_='description')
        # the following are research notes for the logic for no description in a div (bad data)
        # check for value in description (or else it is NoneType)
        # NoneType = type(None)
        #if isinstance(type(desc), NoneType):
        #if desc is not None:
        #
        # some of divs don't have a description in them so we check for this (len == 0). If we didn't then crash.
        if len( desc.get_text ( strip = True )) == 0:
            #print("No description")
            desc = "No description available."
        else:
            #print(i)
            desc = desc.string.strip()

        descriptionList[name] = desc
        #print("Name, img, Desc = ", name, img['src'], desc)
        
        # the following code works but (and should be put in a function) but we only do this once
        filename = os.path.basename(img['src'])
        #
        image = "https://talendforge.org/components/" + img['src']
        #
        # get icon file and write it locally; this takes awhile so we only do it once
        # create the images directory first
        with open('img/'+filename, 'wb') as f2:
            res = requests.get(image)
            f2.write(res.content)
            f2.close()

        # the following logic further categorizes the components to make the data viz graphic more readable
        matchlist = matchparent(name) # do we need to create another level?
        if matchlist:                 # found a match, create a new level.
            matcheditem = family + matchlist[0]
            if (not(matcheditem in matches)): # create another level below 'family'
                matches[matcheditem] = matcheditem
                out = root+family + "."+ matchlist[0] +",\n" # kludgy
                f.write(out)
                #print(root+family + "."+ matchlist[0] +",")
            if(len(matchlist) == 2): # create yet another level below 'level1'; no more, max reached.
                checkitem = family+matchlist[0]+matchlist[1]
                if (not(checkitem in matchesL2)): 
                    matchesL2[checkitem] = checkitem
                    out = root+family + "."+ matchlist[0] + "." + matchlist[1] + ",\n"
                    f.write(out)
                    #print(root+family + "."+ matchlist[0] + "." + matchlist[1] + ",")
                
                out = root+family + "."+ matchlist[0] + "."+ matchlist[1] + "." + name +"," + str(i+j) + "\n"
                f.write(out)
                #print(root+family + "."+ matchlist[0] + "."+ matchlist[1] + "." + name +",",i+j)
            else:
                out = root+family + "."+ matchlist[0] + "." + name +"," + str(i+j) + "\n"
                f.write(out)
                #print(root+family + "."+ matchlist[0] + "." + name +",",i+j) 
        else: # edge node
            out = root+family + "." + name + "," + str(i+j) + "\n"
            f.write(out)
            #print(root+family + "." + name + ",",i+j)
        outputString = ""

        i+=1 # component counter
f.close()
#print (descriptionList)
json_string = json.dumps(descriptionList)
f = open("ComponentDescriptionsV8-2023.json","w")
f.write(json_string)
f.close()
json_string = json.dumps(iconList)
f = open("ComponentIconsV8-2023.json","w")
f.write(json_string)
f.close()
# output description list in the following format:
# component Name: component Description
    
# current stats are 43 families and 1399 components!
print("Statistics:\n Number of families/categories:\t", j,"\n Number of scraped components:\t",i,"\n Number of actual components:\t", len(seen))
# Out:
# family, duplicate name Cloud tGSBucketCreate
# family, duplicate name Cloud tGSBucketDelete
# family, duplicate name Cloud tGSBucketExist
# family, duplicate name Cloud tGSBucketList
# family, duplicate name Cloud tGSClose
# family, duplicate name Cloud tGSConnection
# family, duplicate name Cloud tGSCopy
# family, duplicate name Cloud tGSDelete
# family, duplicate name Cloud tGSGet
# family, duplicate name Cloud tGSList
# family, duplicate name Cloud tGSPut
# family, duplicate name Cloud tMarketoBulkExec
# family, duplicate name Cloud tMarketoCampaign
# family, duplicate name Cloud tMarketoConnection
# family, duplicate name Cloud tMarketoInput
# family, duplicate name Cloud tMarketoListOperation
# family, duplicate name Cloud tMarketoOutput
# family, duplicate name Cloud tNetsuiteConnection
# family, duplicate name Cloud tNetsuiteInput
# family, duplicate name Cloud tNetsuiteOutput
# family, duplicate name Cloud tSalesforceBulkExec
# family, duplicate name Cloud tSalesforceConnection
# family, duplicate name Cloud tSalesforceEinsteinBulkExec
# family, duplicate name Cloud tSalesforceEinsteinOutputBulkExec
# family, duplicate name Cloud tSalesforceGetDeleted
# family, duplicate name Cloud tSalesforceGetServerTimestamp
# family, duplicate name Cloud tSalesforceGetUpdated
# family, duplicate name Cloud tSalesforceInput
# family, duplicate name Cloud tSalesforceOutput
# family, duplicate name Cloud tSalesforceOutputBulk
# family, duplicate name Cloud tSalesforceOutputBulkExec
# family, duplicate name Cloud tServiceNowConnection
# family, duplicate name Cloud tServiceNowInput
# family, duplicate name Cloud tServiceNowOutput
# family, duplicate name Cloud tWorkdayInput
# family, duplicate name Connectivity cAWSConnection
# family, duplicate name Connectivity cAWSS3
# family, duplicate name Connectivity cAWSSES
# family, duplicate name Connectivity cAWSSNS
# family, duplicate name Connectivity cAWSSQS
# family, duplicate name Core cMessagingEndpoint
# family, duplicate name Databases tAmazonAuroraClose
# family, duplicate name Databases tAmazonAuroraCommit
# family, duplicate name Databases tAmazonAuroraConnection
# family, duplicate name Databases tAmazonAuroraInput
# family, duplicate name Databases tAmazonAuroraInvalidRows
# family, duplicate name Databases tAmazonAuroraOutput
# family, duplicate name Databases tAmazonAuroraRollback
# family, duplicate name Databases tAmazonAuroraRow
# family, duplicate name Databases tAmazonAuroraValidRows
# family, duplicate name Databases tAmazonMysqlClose
# family, duplicate name Databases tAmazonMysqlCommit
# family, duplicate name Databases tAmazonMysqlConnection
# family, duplicate name Databases tAmazonMysqlInput
# family, duplicate name Databases tAmazonMysqlOutput
# family, duplicate name Databases tAmazonMysqlRollback
# family, duplicate name Databases tAmazonMysqlRow
# family, duplicate name Databases tAmazonOracleClose
# family, duplicate name Databases tAmazonOracleCommit
# family, duplicate name Databases tAmazonOracleConnection
# family, duplicate name Databases tAmazonOracleInput
# family, duplicate name Databases tAmazonOracleOutput
# family, duplicate name Databases tAmazonOracleRollback
# family, duplicate name Databases tAmazonOracleRow
# family, duplicate name Databases tAmazonRedshiftManage
# family, duplicate name Databases tAzureSynapseBulkExec
# family, duplicate name Databases tAzureSynapseClose
# family, duplicate name Databases tAzureSynapseCommit
# family, duplicate name Databases tAzureSynapseConnection
# family, duplicate name Databases tAzureSynapseInput
# family, duplicate name Databases tAzureSynapseOutput
# family, duplicate name Databases tAzureSynapseRollback
# family, duplicate name Databases tAzureSynapseRow
# family, duplicate name Databases tCosmosDBBulkLoad
# family, duplicate name Databases tCosmosDBConnection
# family, duplicate name Databases tCosmosDBInput
# family, duplicate name Databases tCosmosDBOutput
# family, duplicate name Databases tCosmosDBRow
# family, duplicate name Databases tDB2SCD
# family, duplicate name Databases tDB2SCDELT
# family, duplicate name Databases tGreenplumSCD
# family, duplicate name Databases tHiveClose
# family, duplicate name Databases tHiveConnection
# family, duplicate name Databases tHiveCreateTable
# family, duplicate name Databases tHiveLoad
# family, duplicate name Databases tHiveRow
# family, duplicate name Databases tInformixSCD
# family, duplicate name Databases tJDBCSCDELT
# family, duplicate name Databases tMSSqlSCD
# family, duplicate name Databases tMysqlSCD
# family, duplicate name Databases tMysqlSCDELT
# family, duplicate name Databases tNetezzaSCD
# family, duplicate name Databases tOracleSCD
# family, duplicate name Databases tOracleSCDELT
# family, duplicate name Databases tPostgresPlusSCD
# family, duplicate name Databases tPostgresPlusSCDELT
# family, duplicate name Databases tPostgresqlSCD
# family, duplicate name Databases tPostgresqlSCDELT
# family, duplicate name Databases tRedshiftBulkExec
# family, duplicate name Databases tRedshiftClose
# family, duplicate name Databases tRedshiftCommit
# family, duplicate name Databases tRedshiftConnection
# family, duplicate name Databases tRedshiftInput
# family, duplicate name Databases tRedshiftOutputBulk
# family, duplicate name Databases tRedshiftOutputBulkExec
# family, duplicate name Databases tRedshiftRollback
# family, duplicate name Databases tRedshiftRow
# family, duplicate name Databases tRedshiftUnload
# family, duplicate name Databases tSybaseSCD
# family, duplicate name Databases tSybaseSCDELT
# family, duplicate name Databases tTeradataSCD
# family, duplicate name Databases tTeradataSCDELT
# family, duplicate name Databases tVerticaSCD
# family, duplicate name Databases NoSQL tCassandraBulkExec
# family, duplicate name Databases NoSQL tCassandraClose
# family, duplicate name Databases NoSQL tCassandraConnection
# family, duplicate name Databases NoSQL tCassandraOutput
# family, duplicate name Databases NoSQL tCassandraOutputBulk
# family, duplicate name Databases NoSQL tCassandraOutputBulkExec
# family, duplicate name Databases NoSQL tCassandraRow
# family, duplicate name Databases NoSQL tDynamoDBOutput
# family, duplicate name Databases NoSQL tHBaseClose
# family, duplicate name Databases NoSQL tHBaseConnection
# family, duplicate name Databases NoSQL tMapRDBClose
# family, duplicate name Databases NoSQL tMapRDBConnection
# family, duplicate name Databases NoSQL tMarkLogicBulkLoad
# family, duplicate name Databases NoSQL tMarkLogicClose
# family, duplicate name Databases NoSQL tMarkLogicConnection
# family, duplicate name Databases NoSQL tMarkLogicInput
# family, duplicate name Databases NoSQL tMarkLogicOutput
# family, duplicate name Databases NoSQL tMongoDBBulkLoad
# family, duplicate name Databases NoSQL tMongoDBClose
# family, duplicate name Databases NoSQL tMongoDBConnection
# family, duplicate name Databases NoSQL tMongoDBGridFSDelete
# family, duplicate name Databases NoSQL tMongoDBGridFSGet
# family, duplicate name Databases NoSQL tMongoDBGridFSList
# family, duplicate name Databases NoSQL tMongoDBGridFSProperties
# family, duplicate name Databases NoSQL tMongoDBGridFSPut
# family, duplicate name Databases NoSQL tMongoDBOutput
# family, duplicate name Databases NoSQL tMongoDBRow
# family, duplicate name Databases NoSQL tNeo4jBatchOutput
# family, duplicate name Databases NoSQL tNeo4jBatchOutputRelationship
# family, duplicate name Databases NoSQL tNeo4jBatchSchema
# family, duplicate name Databases NoSQL tNeo4jClose
# family, duplicate name Databases NoSQL tNeo4jConnection
# family, duplicate name Databases NoSQL tNeo4jImportTool
# family, duplicate name Databases NoSQL tNeo4jInput
# family, duplicate name Databases NoSQL tNeo4jRow
# family, duplicate name Databases NoSQL tNeo4jv4Close
# family, duplicate name Databases NoSQL tNeo4jv4Connection
# family, duplicate name Databases NoSQL tNeo4jv4Input
# family, duplicate name Databases NoSQL tNeo4jv4Output
# family, duplicate name Databases NoSQL tNeo4jv4Row
# family, duplicate name Data_Quality tDuplicateRow
# family, duplicate name Data_Quality tMSSqlInvalidRows
# family, duplicate name Data_Quality tMSSqlValidRows
# family, duplicate name Data_Quality tMySQLInvalidRows
# family, duplicate name Data_Quality tMySQLValidRows
# family, duplicate name Data_Quality tOracleInvalidRows
# family, duplicate name Data_Quality tOracleValidRows
# family, duplicate name Data_Quality tPostgresqlInvalidRows
# family, duplicate name Data_Quality tPostgresqlValidRows
# family, duplicate name Data_Quality tSAPHanaInvalidRows
# family, duplicate name Data_Quality tSAPHanaValidRows
# family, duplicate name ELT tAccessConnection
# family, duplicate name ELT tAS400Connection
# family, duplicate name ELT tDB2Connection
# family, duplicate name ELT tDeltaLakeConnection
# family, duplicate name ELT tExasolConnection
# family, duplicate name ELT tFirebirdConnection
# family, duplicate name ELT tGreenplumConnection
# family, duplicate name ELT tJDBCConnection
# family, duplicate name ELT tMSSqlConnection
# family, duplicate name ELT tMysqlConnection
# family, duplicate name ELT tNetezzaConnection
# family, duplicate name ELT tOracleConnection
# family, duplicate name ELT tPostgresPlusConnection
# family, duplicate name ELT tPostgresqlConnection
# family, duplicate name ELT tSAPHanaConnection
# family, duplicate name ELT tSingleStoreConnection
# family, duplicate name ELT tSQLiteConnection
# family, duplicate name ELT tSybaseConnection
# family, duplicate name ELT tTeradataConnection
# family, duplicate name File tChangeFileEncoding
# family, duplicate name File tHDFSCompare
# family, duplicate name File tHDFSConnection
# family, duplicate name File tHDFSCopy
# family, duplicate name File tHDFSDelete
# family, duplicate name File tHDFSExist
# family, duplicate name File tHDFSGet
# family, duplicate name File tHDFSInput
# family, duplicate name File tHDFSList
# family, duplicate name File tHDFSOutput
# family, duplicate name File tHDFSOutputRaw
# family, duplicate name File tHDFSProperties
# family, duplicate name File tHDFSPut
# family, duplicate name File tHDFSRename
# family, duplicate name File tHDFSRowCount
# family, duplicate name File tSqoopExport
# family, duplicate name File tSqoopImport
# family, duplicate name File tSqoopImportAllTables
# family, duplicate name File tSqoopMerge
# family, duplicate name Orchestration tFileList
# family, duplicate name Processing tSurviveFields
# family, duplicate name Storage tBigQueryConfiguration
# family, duplicate name Storage tCassandraConfiguration
# family, duplicate name Storage tDynamoDBConfiguration
# family, duplicate name Storage tHBaseConfiguration
# family, duplicate name Storage tJDBCConfiguration
# family, duplicate name Storage tKuduConfiguration
# family, duplicate name Storage tMapRDBConfiguration
# family, duplicate name Storage tMysqlConfiguration
# family, duplicate name Storage tOracleConfiguration
# family, duplicate name Storage tRedshiftConfiguration
# family, duplicate name Storage tSnowflakeConfiguration
# family, duplicate name Storage tTeradataConfiguration
# family, duplicate name System tRunJob
# family, duplicate name XML tAdvancedFileOutputXML
# family, duplicate name XML tEDIFACTtoXML
# family, duplicate name XML tWriteXMLField
# family, duplicate name XML tXMLMap
# Statistics:
#  Number of families/categories:	 44
#  Number of scraped components:	 1304
#  Number of actual components:	 1083
